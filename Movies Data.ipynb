# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data=pd.read_csv("/home/hammadali08/Videos/CSV file/Moviesdata.csv")

# %%
num1=list(np.array([12,4,1,3,22,45,11]))
num2=list(np.array([45,65,23,43,12,23,45]))
no=list(np.array([1,2,3,4,5,6,7]))

# %%
Data.head(3
        )
# Out:
#    Unnamed: 0  MovieId             Title  \
# 0           0        1  Toy Story (1995)
# 1           1        1  Toy Story (1995)
# 2           2        1  Toy Story (1995)
#
#                                         Genres  userId_x  rating  timestamp_x  \
# 0  Adventure|Animation|Children|Comedy|Fantasy         1     4.0    964982703
# 1  Adventure|Animation|Children|Comedy|Fantasy         1     4.0    964982703
# 2  Adventure|Animation|Children|Comedy|Fantasy         1     4.0    964982703
#
#    userId_y    tag  timestamp_y  imdbId  tmdbId
# 0       336  pixar   1139045764  114709   862.0
# 1       474  pixar   1137206825  114709   862.0
# 2       567    fun   1525286013  114709   862.0

# %%
plt.scatter(num1,no,label="num1")
plt.legend()

# %%
mean=np.mean(num1)
mean2=np.mean(num2)
median=np.median(num1)
median2=np.median(num2)

# %%
plt.figure(figsize=(10,3))
plt.scatter(num1,no,color="Green",label="num1")
(plt.scatter(num2,no,color="red",label="num2"))
plt.plot([mean]*7,no,color="blue",label="mean")
plt.plot([mean2]*7,no,color="yellow",label="mean")
plt.plot([median]*7,no,color="yellow",label="median")
plt.plot([median2]*7,no,color="brown",label="median2""")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.title("Movie Rating")
plt.scatter(num2,no,color="Green",label="num1")
(plt.scatter(num1,no,color="red",label="num2"))
plt.plot(num2,no)
plt.plot(num1,no)
plt.xlabel("Numbers")
plt.ylabel("Sample")
plt.show()

# %%
X=list(np.array(['A','B','C','D','E','F','G']))
plt.bar(X,num2)
plt.title("Bar Chart")
print(num2)
plt.xlabel("Movies")
plt.ylabel("Rating")
plt.show()
# Out:
# [np.int64(45), np.int64(65), np.int64(23), np.int64(43), np.int64(12), np.int64(23), np.int64(45)]

# %%
size=list(np.array([30,40,15,15]))
label=list(np.array(['A','B','C','D']))
plt.pie(size,labels=label,autopct='%1.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=np.random.randn(10000)
plt.hist(data,bins=100,edgecolor="red")

plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(num1,no,color="Green",label="num1")
plt.scatter(num2,no,color="red",label="num2")
plt.title("Scatter Plot")
plt.xlabel("Movies")
plt.ylabel("Rating")
plt.legend()
plt.show()

# %%
data=list(np.random.normal(5,10,100))
data2=list(np.random.normal(25,10,100))
plt.figure(figsize=(6,4))
sns.boxplot([data,data2], patch_artist=True)
plt.title("Box Plot")
plt.xlabel("values")
plt.ylabel("values")
plt.xticks([0, 1], ["Data1", "Data2"])
plt.show()

# %%
data1 = np.random.normal(60, 5, 100)
data2 = np.random.normal(45, 8, 100)

plt.figure(figsize=(8, 5))
plt.boxplot([data1, data2], tick_labels=['Group 1', 'Group 2'], patch_artist=True)
plt.title("Boxplot of Two Groups")
plt.ylabel("Values")
plt.show()

# %%
#GPT ki aulaaad
data = list(np.random.normal(5, 10, 100))
data2 = list(np.random.normal(25, 10, 100))
# ✅ Fix: pass data as list of lists, and use correct 'names' for x-tick labels
sns.boxplot(data=[data, data2])
plt.title("Box Plot")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.xticks([0, 1], ["Data1", "Data2"])  # ✅ Correctly label the two boxplots
plt.show()

# %%
data=list(np.random.normal(5,10,100))
data2=list(np.random.normal(25,10,100))
plt.figure(figsize=(6,4))
sns.violinplot([data,data2])
plt.title("violin plot")
plt.xlabel("values")
plt.ylabel("Points")
plt.xticks([0, 1], ["Data1", "Data2"])
plt.show()

# %%
data=np.random.randn(10,10)
sns.heatmap(data,annot=True)
plt.title("Heatmap")
plt.show()

# %%
plt.fill_between(num1,num2,no,color="blue",alpha=0.3)
plt.title("Fill Between")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %%
mad1=np.sum(np.abs(num1-mean))/len(num1)
mad1
# Out:
# np.float64(11.142857142857142)

# %%
mad2=np.sum(np.abs(num2-mean2))/len(num2)
mad2
# Out:
# np.float64(14.775510204081632)

# %%
Data.isnull().sum()
# Out:
# Unnamed: 0     0
# MovieId        0
# Title          0
# Genres         0
# userId_x       0
# rating         0
# timestamp_x    0
# userId_y       0
# tag            0
# timestamp_y    0
# imdbId         0
# tmdbId         0
# dtype: int64

# %%
Data.head(5
          )
# Out:
#    Unnamed: 0  MovieId             Title  \
# 0           0        1  Toy Story (1995)
# 1           1        1  Toy Story (1995)
# 2           2        1  Toy Story (1995)
# 3           3        1  Toy Story (1995)
# 4           4        1  Toy Story (1995)
#
#                                         Genres  userId_x  rating  timestamp_x  \
# 0  Adventure|Animation|Children|Comedy|Fantasy         1     4.0    964982703
# 1  Adventure|Animation|Children|Comedy|Fantasy         1     4.0    964982703
# 2  Adventure|Animation|Children|Comedy|Fantasy         1     4.0    964982703
# 3  Adventure|Animation|Children|Comedy|Fantasy         5     4.0    847434962
# 4  Adventure|Animation|Children|Comedy|Fantasy         5     4.0    847434962
#
#    userId_y    tag  timestamp_y  imdbId  tmdbId
# 0       336  pixar   1139045764  114709   862.0
# 1       474  pixar   1137206825  114709   862.0
# 2       567    fun   1525286013  114709   862.0
# 3       336  pixar   1139045764  114709   862.0
# ...

# %%
np.percentile(Data["rating"],10)
# Out:
# np.float64(3.0)

# %%
np.median(Data["rating"])
# Out:
# np.float64(4.0)

# %%
np.percentile(Data["userId_y"],10)
# Out:
# np.float64(184.0)

# %%
np.percentile(Data["userId_y"],1)
# Out:
# np.float64(62.0)

# %%
Data.describe()
# Out:
#           Unnamed: 0        MovieId       userId_x         rating  \
# count  233193.000000  233193.000000  233193.000000  233193.000000
# mean   116609.122435   12321.029748     309.676045       3.966609
# std     67324.980565   28244.911441     178.203517       0.968582
# min         0.000000       1.000000       1.000000       0.500000
# 25%     58298.000000     296.000000     156.000000       3.500000
# 50%    116616.000000    1198.000000     309.000000       4.000000
# 75%    174914.000000    4638.000000     460.000000       5.000000
# max    233212.000000  193565.000000     610.000000       5.000000
#
#         timestamp_x       userId_y   timestamp_y        imdbId         tmdbId
# count  2.331930e+05  233193.000000  2.331930e+05  2.331930e+05  233193.000000
# mean   1.213510e+09     470.677893  1.384779e+09  2.610761e+05    9379.040996
# std    2.250472e+08     153.333902  1.534595e+08  4.414578e+05   36944.632021
# ...

# %%
#The dots show the "OUTLIERS" of DATA
sns.boxplot(x=Data["userId_y"])
plt.show()

# %%
sns.histplot(Data["userId_y"])
plt.show()

# %%
Data["userId_y"].hist()
# Out:
# <Axes: >

# %%
#This is right SKEW
Data["userId_y"].skew()
# Out:
# np.float64(-1.5784157341672325)

# %%
#Creating Random data to check SKEW type
normal=np.random.normal(5,100,100)

# %%
normal
# Out:
# array([ 265.70485082, -130.34494987,  114.97769198,  171.6627982 ,
#          70.46554762,    7.4962298 ,   71.57990624,   79.69630876,
#        -134.08985968, -103.04789676,    8.23993296,   77.3002605 ,
#          71.50777772, -276.57045938,   75.29004094,  -10.20512944,
#          56.58298073, -145.8616918 ,  173.86850227,  -61.70535181,
#          92.77929329,   16.07007119,   71.80146111,   -6.55986972,
#          29.46645023, -129.31401199, -150.43549294,   67.35104659,
#          56.65278728,  -29.96388255, -156.80080417,   67.15974766,
#         -39.11078536,   55.41430788,   -3.01859257,   40.13779024,
#         158.69306194,   87.60886721,   80.76558686,  125.67762382,
#          91.05139692, -130.13376459, -134.46729923,   28.95309263,
#        -145.54690219, -131.65578481,   37.27386079,  162.81425444,
#        -132.8956757 ,  -24.34045542,   78.03021896,  -18.15648691,
#          49.3902608 ,   19.00331308,  -92.2013308 ,  -14.62013884,
# ...

# %%
sns.histplot(normal)
plt.show()

# %%
frame=pd.DataFrame(normal)
frame
# Out:
#              0
# 0   265.704851
# 1  -130.344950
# 2   114.977692
# 3   171.662798
# 4    70.465548
# ..         ...
# 95   28.043217
# 96  -36.072747
# 97  -28.396124
# 98 -133.142986
# 99  -41.650106
#
# [100 rows x 1 columns]

# %%
frame.skew()
# Out:
# 0   -0.058089
# dtype: float64

# %%
sns.histplot(frame)
plt.show()

# %%
#Creating perfect Normal SKEW
perfect=[1, 2, 3, 4, 5, 6, 7, 8,
8, 9, 10, 11, 12, 13, 14, 15

]

# %%
perfect1=pd.DataFrame(perfect)

# %%
perfect1.skew()
# Out:
# 0    0.0
# dtype: float64

# %%
sns.histplot(perfect1)
plt.show()

# %%
perfect1.mean(),perfect1.mode()[0],perfect1.median()
# Out:
# (0    8.0
#  dtype: float64,
#  0    8
#  Name: 0, dtype: int64,
#  0    8.0
#  dtype: float64)

# %%
Data.isnull().sum()
# Out:
# Unnamed: 0     0
# MovieId        0
# Title          0
# Genres         0
# userId_x       0
# rating         0
# timestamp_x    0
# userId_y       0
# tag            0
# timestamp_y    0
# imdbId         0
# tmdbId         0
# dtype: int64
