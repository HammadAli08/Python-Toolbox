# %% [markdown]
# # Scalling is used to Shrink the data
# # Types: Standardization and Normalization

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('CSV Files/car_data.csv')
data
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
data.fillna({'Price': data['Price'].mean()}, inplace = True)

# %%
data.fillna({'Odometer (KM)': data['Odometer (KM)'].mean()}, inplace = True)

# %%
data.isnull().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)     0
# Doors            50
# Price             0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(data[['Odometer (KM)']])
# Out:
# StandardScaler()

# %%
ss.transform(data[['Odometer (KM)']])
# Out:
# array([[-1.42359836e+00],
#        [ 9.13101616e-01],
#        [-6.91417611e-01],
#        [ 3.43363580e-01],
#        [ 7.47642999e-01],
#        [-1.31631842e+00],
#        [ 4.78380902e-01],
#        [ 4.32385700e-16],
#        [-1.06260459e-02],
#        [-1.19186419e+00],
#        [ 5.37332127e-01],
#        [-1.69565351e+00],
#        [-4.30103827e-01],
#        [ 4.34967647e-02],
#        [ 1.01886618e+00],
#        [ 1.10442568e+00],
#        [-5.12721711e-01],
#        [ 9.35015189e-01],
#        [-9.39865528e-01],
#        [ 1.25637959e+00],
#        [-9.52198651e-02],
#        [-1.49514803e+00],
#        [ 2.59854297e-01],
#        [-1.75046792e-02],
#        [ 6.16027852e-01],
#        [-8.07346221e-02],
#        [ 7.30008144e-01],
#        [-7.20105821e-01],
#        [-1.10780521e+00],
#        [-2.85979373e-01],
#        [-1.44450168e+00],
#        [-3.37011999e-01],
#        [ 1.07772826e+00],
#        [ 3.31314829e-01],
#        [-8.81062870e-01],
# ...

# %%
data['Odometer (KM) SS']=ss.transform(data[['Odometer (KM)']])

# %%
data
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Odometer (KM) SS
# 0     Honda  White        35431.0    4.0  15323.0         -1.423598
# 1       BMW   Blue       192714.0    5.0  19943.0          0.913102
# 2     Honda  White        84714.0    4.0  28343.0         -0.691418
# 3    Toyota  White       154365.0    4.0  13434.0          0.343364
# 4    Nissan   Blue       181577.0    3.0  14043.0          0.747643
# ..      ...    ...            ...    ...      ...               ...
# 995  Toyota  Black        35820.0    4.0  32042.0         -1.417819
# 996     NaN  White       155144.0    3.0   5716.0          0.354937
# 997  Nissan   Blue        66604.0    4.0  31570.0         -0.960472
# 998   Honda  White       215883.0    4.0   4001.0          1.257316
# 999  Toyota   Blue       248360.0    4.0  12732.0          1.739815
#
# [1000 rows x 6 columns]

# %%
plt.subplot(2,1,1)
plt.title('Odometer (KM) Before')
sns.distplot(data['Odometer (KM)'])
plt.show()

plt.subplot(2,1,2)
plt.title('Odometer (KM) After')
sns.distplot(data['Odometer (KM) SS'])
plt.show()
# Out:
# /tmp/ipykernel_13445/3716905315.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Odometer (KM)'])
# /tmp/ipykernel_13445/3716905315.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Odometer (KM) SS'])

# %%
ss.fit(data[['Price']])
# Out:
# StandardScaler()

# %%
ss.transform(data[['Price']])
# Out:
# array([[-8.61022599e-02],
#        [ 4.66529439e-01],
#        [ 1.47131435e+00],
#        [-3.12059247e-01],
#        [-2.39212341e-01],
#        [ 9.37821407e-01],
#        [-9.05480428e-01],
#        [ 5.09950501e-01],
#        [-7.97705285e-01],
#        [ 1.27274971e+00],
#        [ 2.58594868e-02],
#        [-1.18215513e+00],
#        [ 1.03610700e-01],
#        [-5.88733948e-01],
#        [ 3.47271040e-01],
#        [ 2.95676216e-02],
#        [ 2.20361115e+00],
#        [ 1.35668123e-01],
#        [-8.29403856e-01],
#        [-1.20009772e+00],
#        [ 9.67366868e-01],
#        [ 1.62801294e+00],
#        [ 7.71074959e-01],
#        [ 6.21912248e-01],
#        [-2.11580756e-01],
#        [-4.26811979e-02],
#        [-3.22824799e-01],
#        [-6.05121511e-01],
#        [-1.18514556e+00],
#        [-2.93877425e-01],
#        [ 9.43323800e-01],
#        [-1.09770535e+00],
#        [-8.02968444e-01],
#        [-7.49140681e-01],
#        [ 1.76218371e-01],
# ...

# %%
data["Price SS"]=ss.transform(data[['Price']])

# %%
plt.subplot(2,1,1)
plt.title('Price Before')
sns.distplot(data['Price'])
plt.show()

plt.subplot(2,1,2)
plt.title('Price After')
sns.distplot(data['Price SS'])
plt.show()
# Out:
# /tmp/ipykernel_13445/3432147838.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# /tmp/ipykernel_13445/3432147838.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price SS'])

# %%
data
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Odometer (KM) SS  Price SS
# 0     Honda  White        35431.0    4.0  15323.0         -1.423598 -0.086102
# 1       BMW   Blue       192714.0    5.0  19943.0          0.913102  0.466529
# 2     Honda  White        84714.0    4.0  28343.0         -0.691418  1.471314
# 3    Toyota  White       154365.0    4.0  13434.0          0.343364 -0.312059
# 4    Nissan   Blue       181577.0    3.0  14043.0          0.747643 -0.239212
# ..      ...    ...            ...    ...      ...               ...       ...
# 995  Toyota  Black        35820.0    4.0  32042.0         -1.417819  1.913779
# 996     NaN  White       155144.0    3.0   5716.0          0.354937 -1.235265
# 997  Nissan   Blue        66604.0    4.0  31570.0         -0.960472  1.857319
# 998   Honda  White       215883.0    4.0   4001.0          1.257316 -1.440409
# 999  Toyota   Blue       248360.0    4.0  12732.0          1.739815 -0.396031
#
# [1000 rows x 7 columns]

# %%
data.describe()
# Out:
#        Odometer (KM)       Doors         Price  Odometer (KM) SS      Price SS
# count    1000.000000  950.000000   1000.000000      1.000000e+03  1.000000e+03
# mean   131253.237895    4.011579  16042.814737      4.334311e-16 -1.847411e-16
# std     67343.562285    0.382539   8364.181325      1.000500e+00  1.000500e+00
# min     10148.000000    3.000000   2796.000000     -1.799219e+00 -1.584548e+00
# 25%     72503.000000    4.000000   9798.500000     -8.728323e-01 -7.469278e-01
# 50%    131253.237895    4.000000  14965.000000      4.323857e-16 -1.289252e-01
# 75%    190259.750000    4.000000  20322.000000      8.766397e-01  5.118644e-01
# max    249860.000000    5.000000  52458.000000      1.762100e+00  4.355884e+00

# %%
data.fillna({'Make':data['Make'].mode()[0]}, inplace = True)
data.fillna({'Colour':data['Colour'].mode()[0]}, inplace = True)
data.fillna({'Doors':data['Doors'].mode()[0]}, inplace = True)
data.isnull().sum()
# Out:
# Make                0
# Colour              0
# Odometer (KM)       0
# Doors               0
# Price               0
# Odometer (KM) SS    0
# Price SS            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)
