# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
a=[2,3,4,5]
b=[6,7,8,9]
c=[10,11,5,10]
num1=list(np.array([12,14,19,23,29,45,39]))
num2=list(np.array([45,65,23,43,12,23,45]))
no=list(np.array([1,2,9,7,5,6,10]))
data=pd.read_csv('../CSV Files/Students.csv'
                 )

# %%
plt.bar(a,b,color='b',width=0.4,linestyle='-',linewidth=2,edgecolor='k',alpha=0.7,label='Bar chart Label')
plt.bar(a,c,color='g',width=0.4,linestyle='-',linewidth=2,edgecolor='k',alpha=0.7,label='Bar chart Label 2')
plt.title('Bar Chart')
plt.xlabel('Value')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
plt.plot(b,c,color='blue')
plt.scatter(b,c)
plt.show()

# %%
mean=np.mean(num1)
mean2=np.mean(num2)
median=np.median(num1)
median2=np.median(num2)

# %%
plt.figure(figsize=(10,3))
plt.scatter(num1,no,color="Green",label="num1")
(plt.scatter(num2,no,color="red",label="num2"))
plt.plot([mean]*7,no,color="blue",label="mean")
plt.plot([mean2]*7,no,color="yellow",label="mean")
plt.plot([median]*7,no,color="yellow",label="median")
plt.plot([median2]*7,no,color="brown",label="median2""")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.title("Movie Rating")
plt.scatter(num2,no,color="Green",label="num1")
(plt.scatter(num1,no,color="red",label="num2"))
plt.plot(num2,no)
plt.plot(num1,no)
plt.xlabel("Numbers")
plt.ylabel("Sample")
plt.show()

# %%
size=list(np.array([30,40,15,15]))
label=list(np.array(['A','B','C','D']))
plt.pie(size,labels=label,autopct='%1.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data['CGPA (out of 4.00)'].unique()
# Out:
# array([2.61, 3.07, 2.65, 3.66, 2.54, 3.93, 2.91, 3.68, 2.39, 2.82, 3.4 ,
#        2.28, 2.27, 3.94, 3.43, 2.08, 2.8 , 2.87, 3.49, 2.5 , 2.37, 2.16,
#        2.86, 3.38, 2.12, 3.83, 2.88, 2.48, 2.19, 3.87, 3.28, 3.03, 3.31,
#        3.46, 2.1 , 3.13, 2.32, 2.24, 2.68, 2.18, 2.62, 3.96, 2.35, 2.03,
#        3.53, 3.61, 2.69, 2.93, 3.3 , 3.9 , 3.77, 2.52, 3.  , 3.08, 3.37,
#        3.23, 3.89, 3.73, 3.27, 3.6 , 3.35, 3.15, 2.26, 3.62, 3.64, 3.25,
#        2.41, 2.55, 2.43, 2.75, 3.24, 2.67, 2.77, 3.36, 2.99, 3.39, 2.7 ,
#        2.84, 3.1 , 2.85, 3.14, 3.16, 3.12, 3.48, 2.76, 2.78, 2.6 , 2.2 ,
#        2.11, 3.92, 3.69, 2.71, 3.91, 2.97, 2.17, 3.2 , 3.11, 3.56, 2.23,
#        3.86, 3.95, 3.99, 3.47, 3.09, 3.41, 3.67, 2.45, 2.79, 3.78, 2.29,
#        2.47, 3.76, 3.82, 3.18, 3.42, 2.96, 2.66, 2.51, 2.81, 3.65, 3.06,
#        2.09, 3.85, 3.84, 2.15, 2.33, 2.59, 2.21, 2.34, 3.29, 2.46, 2.53,
#        2.72, 2.06, 2.56, 3.21, 3.88, 2.83, 3.75, 3.97, 3.5 , 2.13, 2.07,
# ...

# %%
Size=list(np.array([2.61, 3.07, 2.65, 3.66, 2.54, 3.93, 2.91, 3.68, 2.39, 2.82, 3.4 ,
       2.28, 2.27, 3.94, 3.43, 2.08, 2.8 , 2.87, 3.49, 2.5 , 2.37, 2.16,
       2.86, 3.38, 2.12, 3.83, 2.88, 2.48, 2.19, 3.87, 3.28, 3.03, 3.31,
       3.46, 2.1 , 3.13, 2.32, 2.24, 2.68, 2.18, 2.62, 3.96, 2.35, 2.03,
       3.53, 3.61, 2.69, 2.93, 3.3 , 3.9 , 3.77, 2.52, 3.  , 3.08, 3.37,
       3.23, 3.89, 3.73, 3.27, 3.6 , 3.35, 3.15, 2.26, 3.62, 3.64, 3.25,
       2.41, 2.55, 2.43, 2.75, 3.24, 2.67, 2.77, 3.36, 2.99, 3.39, 2.7 ,
       2.84, 3.1 , 2.85, 3.14, 3.16, 3.12, 3.48, 2.76, 2.78, 2.6 , 2.2 ,
       2.11, 3.92, 3.69, 2.71, 3.91, 2.97, 2.17, 3.2 , 3.11, 3.56, 2.23,
       3.86, 3.95, 3.99, 3.47, 3.09, 3.41, 3.67, 2.45, 2.79, 3.78, 2.29,
       2.47, 3.76, 3.82, 3.18, 3.42, 2.96, 2.66, 2.51, 2.81, 3.65, 3.06,
       2.09, 3.85, 3.84, 2.15, 2.33, 2.59, 2.21, 2.34, 3.29, 2.46, 2.53,
       2.72, 2.06, 2.56, 3.21, 3.88, 2.83, 3.75, 3.97, 3.5 , 2.13, 2.07,
       3.17, 3.45, 3.51, 2.04, 2.95, 3.63, 3.58, 3.57, 3.81, 3.22, 2.9 ,
       3.05, 3.59, 2.92, 3.54, 2.42, 2.36, 3.79, 2.64, 3.02, 2.31, 2.01,
       3.74, 3.19, 3.52, 3.44, 2.3 , 3.8 , 2.49, 2.02, 2.73, 2.98, 3.7 ,
       2.4 , 3.01, 2.74, 3.98, 2.63, 4.  , 2.58]))
plt.pie(Size,autopct='%1.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(data['CGPA (out of 4.00)'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7ec4b03200>,
# ...
#  [Text(1.0999837265503816, 0.005983420788786276, ''),
#   Text(1.0998358284315781, 0.019003960066904007, ''),
#   Text(1.099531137910271, 0.032113498186040465, ''),
#   Text(1.0990137609020594, 0.04656987597053962, ''),
#   Text(1.098320282696008, 0.06076641028200955, ''),
#   Text(1.0974010779069774, 0.07557032624386738, ''),
#   Text(1.0962123403895763, 0.09120583740971777, ''),
#   Text(1.0948563520034098, 0.1062523810452544, ''),
#   Text(1.0934246372426635, 0.12009397433156123, ''),
#   Text(1.0920562067518176, 0.13195924103613, ''),
#   Text(1.0902538994256912, 0.14610419154519563, ''),
#   Text(1.0884480159925354, 0.15899973736429168, ''),
#   Text(1.0868913625020176, 0.16931380959185793, ''),
#   Text(1.0846090933852655, 0.18336606705165642, ''),
#   Text(1.0816647950691687, 0.20000317774468915, ''),
#   Text(1.0792968133432386, 0.21241089592375126, ''),
#   Text(1.0770807261979767, 0.2233766085623995, ''),
# ...

# %%
data=np.random.randn(10000)
plt.hist(data,bins=100,edgecolor="red")

plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
data=list(np.random.normal(5,10,100))
data2=list(np.random.normal(25,10,100))
plt.figure(figsize=(6,4))
sns.boxplot([data,data2], patch_artist=True)
plt.title("Box Plot")
plt.xlabel("values")
plt.ylabel("values")
plt.xticks([0, 1], ["Data1", "Data2"])
plt.show()

# %%
data=list(np.random.normal(5,10,100))
data2=list(np.random.normal(25,15,100))
plt.figure(figsize=(6,4))
sns.violinplot([data,data2])
plt.title("violin plot")
plt.xlabel("values")
plt.ylabel("Points")
plt.xticks([0, 1], ["Data1", "Data2"])
plt.show()

# %%
plt.show()
plt.fill_between(num1, num2, no, color="blue", alpha=0.3)
plt.title("Fill Between")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %%
sns.lineplot(num1,color='yellow',marker='o',label='num1')
sns.lineplot(num2,color="red",marker='o',label='num2')
plt.title("Line Plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend()
plt.grid(axis='y',linestyle='--')
plt.show()

# %%
df=pd.read_csv('/home/hammadali08/Vidoes/CSV file/cardata.csv')
df=df.head(20)

# %%
sns.lineplot(df['Present_Price'],color='yellow',label='Present_Price',marker='o')
sns.lineplot(df['Selling_Price'],color='Red',label='Selling_Price',marker='o')
plt.title("Line Plot")
plt.xlabel("X axis")
plt.xticks([i for i in range(0,20)])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pd.read_csv('/home/hammadali08/Vidoes/CSV file/countries of the world.csv')
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...
