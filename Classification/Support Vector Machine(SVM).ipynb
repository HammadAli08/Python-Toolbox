# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/Social_Network_Ads.csv")
data.drop(columns=['User ID','Gender'],inplace=True)
data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
sns.scatterplot(x='Age',y='EstimatedSalary',data=data,hue='Purchased')
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
x=data.iloc[:,:-1]
y=data['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=70)

# %%
from sklearn.svm import SVC

# %%
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
 svc.score(x_test,y_test),svc.score(x_train,y_train)
# Out:
# (0.78, 0.7733333333333333)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=svc,legend=2)
# Out:
# /home/hammadali08/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %% [markdown]
# # For Polynomial Data

# %%
data1=pd.read_csv('/home/hammadali08/Vidoes/CSV file/polynomial_logistic_dataset.csv')
data1
# Out:
#           x1        x2  Output
# 0  -0.752759 -2.811425       1
# 1   2.704286  0.818462       1
# 2   1.391964 -1.113864       0
# 3   0.591951  0.051424       0
# 4  -2.063888  2.445399       1
# ..       ...       ...     ...
# 95 -0.037226 -0.904743       0
# 96  0.136397  1.355734       0
# 97 -0.434754  2.382662       0
# 98 -2.847485  2.322519       1
# 99 -2.352651  1.679253       1
#
# [100 rows x 3 columns]

# %%
x1=data1.iloc[:,:-1]
y1=data1['Output']

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.25,random_state=13)

# %%
sv=SVC(kernel='rbf')
sv.fit(x1_train,y1_train)
# Out:
# SVC()

# %%
sv.score(x1_test,y1_test),sv.score(x1_train,y1_train)
# Out:
# (0.84, 0.8533333333333334)

# %%
plot_decision_regions(x1.to_numpy(),y1.to_numpy(),clf=sv,legend=2)
# Out:
# /home/hammadali08/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >
