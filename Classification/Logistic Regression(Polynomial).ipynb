# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/polynomial_logistic_dataset.csv")
data
# Out:
#           x1        x2  Output
# 0  -0.752759 -2.811425       1
# 1   2.704286  0.818462       1
# 2   1.391964 -1.113864       0
# 3   0.591951  0.051424       0
# 4  -2.063888  2.445399       1
# ..       ...       ...     ...
# 95 -0.037226 -0.904743       0
# 96  0.136397  1.355734       0
# 97 -0.434754  2.382662       0
# 98 -2.847485  2.322519       1
# 99 -2.352651  1.679253       1
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x="x1",y="x2",data=data,hue='Output')
plt.legend(loc='upper right')
plt.show()

# %%
x=data.iloc[:,:-1]
y=data['Output']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lg.score(x_test,y_test)
# Out:
# 0.5

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lg,colors="blue,red",legend=2)
plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Decision Boundary")
# Out:
# /home/hammadali08/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Text(0.5, 1.0, 'Decision Boundary')

# %% [markdown]
# # Now trying this dataset with Polynomial Feaures

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=3)

# %%
X=data.iloc[:,:-1]
Y=data['Output']

# %%
pf.fit(X)
# Out:
# PolynomialFeatures(degree=3)

# %%
X=pd.DataFrame(pf.transform(X))
X
# Out:
#       0         1         2         3         4         5          6  \
# 0   1.0 -0.752759 -2.811425  0.566647  2.116326  7.904110  -0.426548
# 1   1.0  2.704286  0.818462  7.313162  2.213356  0.669881  19.776880
# 2   1.0  1.391964 -1.113864  1.937563 -1.550458  1.240693   2.697017
# 3   1.0  0.591951  0.051424  0.350406  0.030441  0.002644   0.207423
# 4   1.0 -2.063888  2.445399  4.259634 -5.047030  5.979976  -8.791409
# ..  ...       ...       ...       ...       ...       ...        ...
# 95  1.0 -0.037226 -0.904743  0.001386  0.033680  0.818559  -0.000052
# 96  1.0  0.136397  1.355734  0.018604  0.184918  1.838015   0.002538
# 97  1.0 -0.434754  2.382662  0.189011 -1.035871  5.677076  -0.082173
# 98  1.0 -2.847485  2.322519  8.108172 -6.613337  5.394092 -23.087901
# 99  1.0 -2.352651  1.679253  5.534969 -3.950698  2.819892 -13.021852
#
#             7          8          9
# 0   -1.593084  -5.949892 -22.221811
# 1    5.985549   1.811549   0.548272
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=48 )

# %%
lg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
lg.score(X_test,Y_test)*100
# Out:
# 95.0

# %% [markdown]
# # Now i will try Polynomial on Diabetes dataset Columns

# %%
Data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/Diabetes.csv")
Data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x2=Data[['BMI','DiabetesPedigreeFunction']]
y2=Data[['Outcome']]

# %%
sns.scatterplot(x=Data['BMI'],y=Data['DiabetesPedigreeFunction'],hue=Data['Outcome'])
# Out:
# <Axes: xlabel='BMI', ylabel='DiabetesPedigreeFunction'>

# %%
from sklearn.preprocessing import PolynomialFeatures
plf=PolynomialFeatures(degree=3)

# %%
plf.fit(x2)
# Out:
# PolynomialFeatures(degree=3)

# %%
x2=pd.DataFrame(plf.transform(x2))
x2
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 x2=pd.DataFrame(plf.transform(x2))
#       2 x2
#
# File ~/.local/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/.local/lib/python3.12/site-packages/sklearn/preprocessing/_polynomial.py:499, in PolynomialFeatures.transform(self, X)
# ...

# %%
x2_test,x2_train,y2_test,y2_train=train_test_split(x2,y2,test_size=0.2,random_state=45)
y2_train
# Out:
#      Outcome
# 195        1
# 51         0
# 66         1
# 437        0
# 665        0
# ..       ...
# 246        0
# 556        0
# 298        1
# 339        1
# 146        0
#
# [154 rows x 1 columns]

# %%
lg.fit(x2_train,y2_train)
# Out:
# /home/hammadali08/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/hammadali08/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lg.score(x2_test,y2_test)*100
# Out:
# 67.91530944625407
