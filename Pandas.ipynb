# %%
import pandas as pd
from pandas.core.algorithms import duplicated

# %%
data=pd.read_csv('factory_worker_data.csv')
Data=pd.read_csv('Students.csv')
data.shape
# Out:
# (1000, 12)

# %% [markdown]
# # Deleting Duplicate Values

# %%
data.duplicated('Sensor_3').sum()
# Out:
# np.int64(51)

# %%
data.drop_duplicates('Sensor_3', inplace=True)

# %%
data.duplicated('Sensor_3').sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (949, 12)

# %%
data.duplicated('Sensor_8').sum()
# Out:
# np.int64(47)

# %%
data.drop_duplicates('Sensor_8', inplace=True)

# %%
data.shape
# Out:
# (902, 12)

# %% [markdown]
# # Making new COLUMN

# %%
data
# Out:
#     WorkerID  Age  Experience Department   Sensor_1   Sensor_2   Sensor_3  \
# 0      W1000   41           4         QC   7.237457  -5.345062        NaN
# 1      W1001   27           4         QC  -6.099276   4.944228   5.751492
# 2      W1002   40          11         QC  14.163983   7.419787  13.026986
# 3      W1003   25           2   Assembly  -8.144112   6.022785   1.759761
# 4      W1004   34           7   Assembly   9.499723   8.917607  12.294359
# ..       ...  ...         ...        ...        ...        ...        ...
# 995    W1995   24           4   Assembly   9.587238   1.885114   4.269326
# 996    W1996   43          21         QC  29.973041  20.812611  25.566959
# 997    W1997   59          37         QC  44.074508  40.501634  46.594357
# 998    W1998   33           7   Assembly  10.258249  13.489234  11.741711
# 999    W1999   31           4   Assembly   0.873051   1.330631  -1.988315
#
#       Sensor_4   Sensor_5   Sensor_6   Sensor_7   Sensor_8
# ...

# %%
data.loc[(data['Department'] == 'QC'),"QC_department"] = "Yes"
data.loc[(data['Department'] != 'QC'),"QC_department"] = "No"

# %%
data
# Out:
#     WorkerID  Age  Experience Department   Sensor_1   Sensor_2   Sensor_3  \
# 0      W1000   41           4         QC   7.237457  -5.345062        NaN
# 1      W1001   27           4         QC  -6.099276   4.944228   5.751492
# 2      W1002   40          11         QC  14.163983   7.419787  13.026986
# 3      W1003   25           2   Assembly  -8.144112   6.022785   1.759761
# 4      W1004   34           7   Assembly   9.499723   8.917607  12.294359
# ..       ...  ...         ...        ...        ...        ...        ...
# 995    W1995   24           4   Assembly   9.587238   1.885114   4.269326
# 996    W1996   43          21         QC  29.973041  20.812611  25.566959
# 997    W1997   59          37         QC  44.074508  40.501634  46.594357
# 998    W1998   33           7   Assembly  10.258249  13.489234  11.741711
# 999    W1999   31           4   Assembly   0.873051   1.330631  -1.988315
#
#       Sensor_4   Sensor_5   Sensor_6   Sensor_7   Sensor_8 QC_department
# ...

# %%
data.loc[(data['Age'] >= 40),"Quadragenarian"] = "Yes"
data.loc[(data['Age'] < 40), "Quadragenarian"] = "No"

# %%
data
# Out:
#     WorkerID  Age  Experience Department   Sensor_1   Sensor_2   Sensor_3  \
# 0      W1000   41           4         QC   7.237457  -5.345062        NaN
# 1      W1001   27           4         QC  -6.099276   4.944228   5.751492
# 2      W1002   40          11         QC  14.163983   7.419787  13.026986
# 3      W1003   25           2   Assembly  -8.144112   6.022785   1.759761
# 4      W1004   34           7   Assembly   9.499723   8.917607  12.294359
# ..       ...  ...         ...        ...        ...        ...        ...
# 995    W1995   24           4   Assembly   9.587238   1.885114   4.269326
# 996    W1996   43          21         QC  29.973041  20.812611  25.566959
# 997    W1997   59          37         QC  44.074508  40.501634  46.594357
# 998    W1998   33           7   Assembly  10.258249  13.489234  11.741711
# 999    W1999   31           4   Assembly   0.873051   1.330631  -1.988315
#
#       Sensor_4   Sensor_5   Sensor_6   Sensor_7   Sensor_8 QC_department  \
# ...

# %% [markdown]
# # TWO SYNTAX column can CONCETENATE

# %%
 data["Id and Department"]=data["WorkerID"]+ " and " + data["Department"]

# %%
data
# Out:
#     WorkerID  Age  Experience Department   Sensor_1   Sensor_2   Sensor_3  \
# 0      W1000   41           4         QC   7.237457  -5.345062        NaN
# 1      W1001   27           4         QC  -6.099276   4.944228   5.751492
# 2      W1002   40          11         QC  14.163983   7.419787  13.026986
# 3      W1003   25           2   Assembly  -8.144112   6.022785   1.759761
# 4      W1004   34           7   Assembly   9.499723   8.917607  12.294359
# ..       ...  ...         ...        ...        ...        ...        ...
# 995    W1995   24           4   Assembly   9.587238   1.885114   4.269326
# 996    W1996   43          21         QC  29.973041  20.812611  25.566959
# 997    W1997   59          37         QC  44.074508  40.501634  46.594357
# 998    W1998   33           7   Assembly  10.258249  13.489234  11.741711
# 999    W1999   31           4   Assembly   0.873051   1.330631  -1.988315
#
#       Sensor_4   Sensor_5   Sensor_6   Sensor_7   Sensor_8 QC_department  \
# ...

# %%
Data
# Out:
#               Name  Age  CGPA (out of 4.00)  Daily Study Hours  \
# 0       Zain Tariq   24                2.61                1.3
# 1     Fatima Nawaz   21                3.07                2.4
# 2     Ahmed Sheikh   22                2.65                5.9
# 3     Zain Qureshi   24                3.66                4.9
# 4    Fatima Sheikh   20                2.54                1.3
# ..             ...  ...                 ...                ...
# 495    Hamza Nawaz   23                2.85                1.1
# 496    Usman Malik   18                2.58                6.7
# 497    Fatima Rana   21                3.23                3.2
# 498      Ali Javed   19                3.82                2.9
# 499  Usman Qureshi   23                2.28                7.8
#
#     Sports Involvement  IQ Score
# 0                  Yes       112
# 1                   No       126
# 2                   No        97
# 3                  Yes       102
# 4                   No        97
# ...

# %%
Data['Expected result']=(Data['Daily Study Hours']/Data["IQ Score"])*100

# %%
Data
# Out:
#               Name  Age  CGPA (out of 4.00)  Daily Study Hours  \
# 0       Zain Tariq   24                2.61                1.3
# 1     Fatima Nawaz   21                3.07                2.4
# 2     Ahmed Sheikh   22                2.65                5.9
# 3     Zain Qureshi   24                3.66                4.9
# 4    Fatima Sheikh   20                2.54                1.3
# ..             ...  ...                 ...                ...
# 495    Hamza Nawaz   23                2.85                1.1
# 496    Usman Malik   18                2.58                6.7
# 497    Fatima Rana   21                3.23                3.2
# 498      Ali Javed   19                3.82                2.9
# 499  Usman Qureshi   23                2.28                7.8
#
#     Sports Involvement  IQ Score  Expected result
# 0                  Yes       112         1.160714
# 1                   No       126         1.904762
# 2                   No        97         6.082474
# ...
