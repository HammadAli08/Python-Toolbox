# %%
import pandas as pd

dataset=pd.read_csv('/home/hammadali08/Personal/CSV file/eng_-french.csv')
dataset=dataset.head(5000)

# %%
dataset = dataset.rename(columns={'English words/sentences': 'English'})
dataset= dataset.rename(columns={'French words/sentences': 'French'})
dataset
# Out:
#              English                  French
# 0                Hi.                  Salut!
# 1               Run!                 Cours !
# 2               Run!                Courez !
# 3               Who?                   Qui ?
# 4               Wow!              Ça alors !
# ...              ...                     ...
# 4995  Don't be rude.   Ne sois pas impolie !
# 4996  Don't be rude.   Ne soyez pas impoli !
# 4997  Don't be rude.  Ne soyez pas impolie !
# 4998  Don't call me.       Ne m'appelle pas.
# 4999  Don't deny it.         Ne le nie pas !
#
# [5000 rows x 2 columns]

# %%
import re
corpus = []
for i in range(0, len(dataset)):
    review = re.sub('[^a-zA-Z0-9]', ' ', dataset['English'][i])
    review = review.lower()
    review = review.split()

    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['hi',
#  'run',
#  'run',
#  'who',
#  'wow',
#  'fire',
#  'help',
#  'jump',
#  'stop',
#  'stop',
#  'stop',
#  'wait',
#  'wait',
#  'go on',
#  'go on',
#  'go on',
#  'hello',
#  'hello',
#  'i see',
#  'i try',
#  'i won',
#  'i won',
#  'i won',
#  'oh no',
#  'attack',
#  'attack',
#  'cheers',
#  'cheers',
#  'cheers',
#  'cheers',
#  'get up',
#  'go now',
#  'go now',
#  'go now',
#  'got it',
#  'got it',
#  'got it',
#  'got it',
#  'got it',
#  'hop in',
#  'hop in',
#  'hug me',
#  'hug me',
#  'i fell',
#  'i fell',
#  'i know',
#  'i left',
#  'i left',
#  'i lied',
#  'i lost',
#  'i paid',
#  'i m 19',
#  'i m ok',
#  'i m ok',
#  'listen',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'really',
#  'really',
#  'really',
#  'thanks',
#  'we try',
#  'we won',
#  'we won',
#  'we won',
#  'we won',
#  'ask tom',
#  'awesome',
#  'be calm',
#  'be calm',
#  'be calm',
#  'be cool',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be kind',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'beat it',
#  'call me',
#  'call me',
#  'call us',
#  'call us',
#  'come in',
#  'come in',
#  'come in',
#  'come in',
#  'come on',
#  'come on',
#  'come on',
#  'come on',
#  'drop it',
#  'drop it',
#  'drop it',
#  'drop it',
#  'get tom',
#  'get out',
#  'get out',
#  'get out',
#  'get out',
#  'get out',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go home',
#  'go home',
#  'go home',
#  'go home',
#  'go slow',
#  'go slow',
#  'goodbye',
#  'goodbye',
#  'hang on',
#  'hang on',
#  'hang on',
#  'hang on',
#  'he quit',
#  'he quit',
#  'he runs',
#  'help me',
#  'help me',
#  'help me',
#  'help us',
#  'help us',
#  'hold it',
#  'hold on',
#  'hug tom',
#  'i agree',
#  'i cried',
#  'i dozed',
#  'i dozed',
#  'i drive',
#  'i smoke',
#  'i snore',
#  'i stink',
#  'i stood',
#  'i stood',
#  'i swore',
#  'i swore',
#  'i tried',
#  'i tried',
#  'i tried',
#  'i waved',
#  'i ll go',
#  'i m tom',
#  'i m fat',
#  'i m fat',
#  'i m fit',
#  'i m hit',
#  'i m hit',
#  'i m ill',
#  'i m sad',
#  'i m shy',
#  'i m wet',
#  'i m wet',
#  'it s me',
#  'join us',
#  'join us',
#  'keep it',
#  'keep it',
#  'kiss me',
#  'kiss me',
#  'me too',
#  'open up',
#  'open up',
#  'perfect',
#  'see you',
#  'see you',
#  'see you',
#  'see you',
#  'show me',
#  'show me',
#  'shut up',
#  'shut up',
#  'shut up',
#  'shut up',
#  'shut up',
#  'skip it',
#  'so long',
#  'take it',
#  'take it',
#  'take it',
#  'take it',
#  'tell me',
#  'tell me',
#  'tom won',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wash up',
#  'wash up',
#  'we know',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'welcome',
#  'who won',
#  'who won',
#  'you run',
#  'am i fat',
#  'am i fat',
#  'ask them',
#  'ask them',
#  'back off',
#  'back off',
#  'back off',
#  'back off',
#  'back off',
#  'back off',
#  'be a man',
#  'be a man',
#  'be still',
#  'be still',
#  'be still',
#  'beats me',
#  'beats me',
#  'call tom',
#  'call tom',
#  'cheer up',
#  'cool off',
#  'cuff him',
#  'drive on',
#  'drive on',
#  'drive on',
#  'drive on',
#  'find tom',
#  'find tom',
#  'fix this',
#  'fix this',
#  'get down',
#  'get down',
#  'get down',
#  'get down',
#  'get down',
#  'get lost',
#  'get lost',
#  'get lost',
#  'get real',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'good job',
#  'good job',
#  'good job',
#  'grab him',
#  'grab him',
#  'have fun',
#  'have fun',
#  'he tries',
#  'he s wet',
#  'help tom',
#  'help tom',
#  'hi guys',
#  'how cute',
#  'how deep',
#  'how nice',
#  'how nice',
#  'how nice',
#  'how nice',
#  'hurry up',
#  'hurry up',
#  'hurry up',
#  'hurry up',
#  'i did ok',
#  'i did ok',
#  'i did it',
#  'i did it',
#  'i failed',
#  'i forgot',
#  'i get it',
#  'i got it',
#  'i got it',
#  'i helped',
#  'i jumped',
#  'i looked',
#  'i moaned',
#  'i nodded',
#  'i obeyed',
#  'i phoned',
#  'i phoned',
#  'i refuse',
#  'i refuse',
#  'i rested',
#  'i rested',
#  'i saw it',
#  'i saw it',
#  'i sighed',
#  'i stayed',
#  'i stayed',
#  'i talked',
#  'i use it',
#  'i use it',
#  'i use it',
#  'i ll pay',
#  'i ll try',
#  'i ll try',
#  'i m back',
#  'i m back',
#  'i m bald',
#  'i m busy',
#  'i m busy',
#  'i m calm',
#  'i m cold',
#  'i m cool',
#  'i m cool',
#  'i m deaf',
#  'i m deaf',
#  'i m done',
#  'i m fair',
#  'i m fair',
#  'i m fair',
#  'i m fast',
#  'i m fine',
#  'i m fine',
#  'i m fine',
#  'i m free',
#  'i m free',
#  'i m free',
#  'i m full',
#  'i m full',
#  'i m game',
#  'i m game',
#  'i m glad',
#  'i m home',
#  'i m late',
#  'i m lazy',
#  'i m lazy',
#  'i m lazy',
#  'i m lazy',
#  'i m okay',
#  'i m okay',
#  'i m rich',
#  'i m safe',
#  'i m sick',
#  'i m sure',
#  'i m sure',
#  'i m sure',
#  'i m sure',
#  'i m tall',
#  'i m thin',
#  'i m tidy',
#  'i m tidy',
#  'i m ugly',
#  'i m ugly',
#  'i m weak',
#  'i m well',
#  'i m well',
#  'i ve won',
#  'i ve won',
#  'it helps',
#  'it hurts',
#  'it works',
#  'it works',
#  'it s tom',
#  'it s fun',
#  'it s fun',
#  'it s his',
#  'it s his',
#  'it s new',
#  'it s new',
#  'it s odd',
#  'it s red',
#  'it s sad',
#  'keep out',
#  'keep out',
#  'kiss tom',
#  'leave it',
#  'leave it',
#  'leave me',
#  'leave us',
#  'leave us',
#  'let s go',
#  'let s go',
#  'look out',
#  'look out',
#  'marry me',
#  'marry me',
#  'may i go',
#  'may i go',
#  'may i go',
#  'save tom',
#  'save tom',
#  'say what',
#  'she came',
#  'she died',
#  'she runs',
#  'sit down',
#  'sit down',
#  'sit down',
#  'sit here',
#  'sit here',
#  'speak up',
#  'speak up',
#  'stand up',
#  'stop tom',
#  'stop tom',
#  'taste it',
#  'taste it',
#  'taste it',
#  'taste it',
#  'tell tom',
#  'tell tom',
#  'terrific',
#  'terrific',
#  'terrific',
#  'they won',
#  'they won',
#  'they won',
#  'they won',
#  'tom came',
#  'tom died',
#  'tom knew',
#  'tom left',
#  'tom left',
#  'tom lied',
#  'tom lies',
#  'tom lost',
#  'tom paid',
#  'too late',
#  'trust me',
#  'trust me',
#  'try hard',
#  'try some',
#  'try some',
#  'try this',
#  'try this',
#  'use this',
#  'use this',
#  'use this',
#  'use this',
#  'warn tom',
#  'warn tom',
#  'watch me',
#  'watch me',
#  'watch us',
#  'watch us',
#  'we agree',
#  'we ll go',
#  'we re ok',
#  'what for',
#  'what for',
#  'what fun',
#  'what fun',
#  'who came',
#  'who died',
#  'who fell',
#  'who quit',
#  'who s he',
#  'write me',
#  'write me',
#  'you lost',
#  'you lost',
#  'after you',
#  'aim fire',
#  'am i late',
#  'answer me',
#  'be seated',
#  'be seated',
#  'birds fly',
#  'bless you',
#  'call home',
#  'calm down',
#  'calm down',
#  'can we go',
#  'can we go',
#  'can we go',
#  'catch tom',
#  'catch tom',
#  'catch him',
#  'chill out',
#  'come back',
#  'come back',
#  'come here',
#  'come here',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come soon',
#  'come soon',
#  'cool down',
#  'did i win',
#  'did i win',
#  'did i win',
#  'do it now',
#  'dogs bark',
#  'dogs bark',
#  'don t ask',
#  'don t cry',
#  'don t die',
#  'don t die',
#  'don t lie',
#  'don t run',
#  'don t run',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'excuse me',
#  'fantastic',
#  'feel this',
#  'feel this',
#  'feel this',
#  'feel this',
#  'follow me',
#  'follow us',
#  'follow us',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'get a job',
#  'get a job',
#  'get a job',
#  'get a job',
#  'get ready',
#  'get ready',
#  'go get it',
#  'go get it',
#  'go inside',
#  'go to bed',
#  'go to bed',
#  'good luck',
#  'good luck',
#  'grab that',
#  'grab that',
#  'grab that',
#  'grab that',
#  'grab this',
#  'grab this',
#  'hands off',
#  'he is ill',
#  'he is old',
#  'he s a dj',
#  'he s good',
#  'he s lazy',
#  'he s mine',
#  'he s rich',
#  'he s sexy',
#  'here i am',
#  'here s 5',
#  'hold fire',
#  'hold fire',
#  'hold this',
#  'hold this',
#  'hold this',
#  'hold this',
#  'how awful',
#  'how weird',
#  'how s tom',
#  'how s tom',
#  'i am cold',
#  'i am good',
#  'i am okay',
#  'i am sick',
#  'i am sure',
#  'i am sure',
#  'i beg you',
#  'i beg you',
#  'i beg you',
#  'i beg you',
#  'i can run',
#  'i can ski',
#  'i cringed',
#  'i cringed',
#  'i cringed',
#  'i exhaled',
#  'i gave up',
#  'i give in',
#  'i give up',
#  'i got hot',
#  'i got hot',
#  'i had fun',
#  'i had fun',
#  'i had fun',
#  'i had fun',
#  'i hate it',
#  'i have it',
#  'i hit tom',
#  'i hope so',
#  'i hurried',
#  'i hurried',
#  'i inhaled',
#  'i knew it',
#  'i like it',
#  'i lost it',
#  'i love it',
#  'i love it',
#  'i mean it',
#  'i mean it',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i need it',
#  'i need it',
#  'i noticed',
#  'i prepaid',
#  'i promise',
#  'i relaxed',
#  'i relaxed',
#  'i retired',
#  'i said no',
#  'i said so',
#  'i saw him',
#  'i saw him',
#  'i saw him',
#  'i saw one',
#  'i saw one',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i see tom',
#  'i shouted',
#  'i tripped',
#  'i tripped',
#  'i want it',
#  'i was new',
#  'i was new',
#  'i will go',
#  'i woke up',
#  'i woke up',
#  'i d agree',
#  'i d leave',
#  'i ll call',
#  'i ll cook',
#  'i ll help',
#  'i ll live',
#  'i ll obey',
#  'i ll pack',
#  'i ll pack',
#  'i ll pack',
#  'i ll pass',
#  'i ll quit',
#  'i ll sing',
#  'i ll stop',
#  'i ll swim',
#  'i ll talk',
#  'i ll talk',
#  'i ll wait',
#  'i ll walk',
#  'i ll work',
#  'i ll work',
#  'i m a cop',
#  'i m a man',
#  'i m alive',
#  'i m alive',
#  'i m alive',
#  'i m alone',
#  'i m alone',
#  'i m angry',
#  'i m angry',
#  'i m armed',
#  'i m armed',
#  'i m awake',
#  'i m blind',
#  'i m broke',
#  'i m clean',
#  'i m clean',
#  'i m crazy',
#  'i m crazy',
#  'i m cured',
#  'i m cured',
#  'i m dizzy',
#  'i m drunk',
#  'i m drunk',
#  'i m drunk',
#  'i m dying',
#  'i m early',
#  'i m first',
#  'i m fussy',
#  'i m fussy',
#  'i m fussy',
#  'i m going',
#  'i m going',
#  'i m going',
#  'i m going',
#  'i m loyal',
#  'i m loyal',
#  'i m lucky',
#  'i m lucky',
#  'i m lucky',
#  'i m lucky',
#  'i m lucky',
#  'i m lying',
#  'i m naked',
#  'i m naked',
#  'i m naked',
#  'i m naked',
#  'i m naked',
#  'i m quiet',
#  'i m ready',
#  'i m ready',
#  'i m ready',
#  'i m right',
#  'i m sober',
#  'i m sorry',
#  'i m sorry',
#  'i m sorry',
#  'i m sorry',
#  'i m sorry',
#  'i m sorry',
#  'i m stuck',
#  'i m timid',
#  'i m tired',
#  'i m tough',
#  'i m tough',
#  'i m tough',
#  'i m tough',
#  'i m yours',
#  'i m yours',
#  'i ve lost',
#  'is tom ok',
#  'is tom ok',
#  'is it bad',
#  'is it far',
#  'is it far',
#  'is it hot',
#  'is it you',
#  'is it you',
#  'is it you',
#  'it failed',
#  'it snowed',
#  'it stinks',
#  'it stinks',
#  'it was ok',
#  'it was ok',
#  'it was ok',
#  'it worked',
#  'it worked',
#  'it s 3 30',
#  'it s 8 30',
#  'it s 8 30',
#  'it s a tv',
#  'it s cold',
#  'it s cold',
#  'it s dark',
#  'it s dead',
#  'it s dead',
#  'it s dead',
#  'it s done',
#  'it s easy',
#  'it s food',
#  'it s free',
#  'it s here',
#  'it s here',
#  'it s hers',
#  'it s hers',
#  'it s late',
#  'it s lost',
#  'it s mine',
#  'it s mine',
#  'it s mine',
#  'it s mine',
#  'it s open',
#  'it s ours',
#  'it s ours',
#  'it s ours',
#  'it s sand',
#  'it s time',
#  'it s time',
#  'it s true',
#  'it s work',
#  'keep calm',
#  'keep that',
#  'keep that',
#  'keep this',
#  'keep this',
#  'let it be',
#  'let it be',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me in',
#  'let me in',
#  'let s ask',
#  'let s eat',
#  'let s see',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'look away',
#  'look away',
#  'look back',
#  'look back',
#  'look here',
#  'look here',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'move over',
#  'move over',
#  'move over',
#  'nice shot',
#  'of course',
#  'of course',
#  'of course',
#  'of course',
#  'of course',
#  'oh please',
#  'oh please',
#  'pardon me',
#  'pardon me',
#  'pardon me',
#  'read this',
#  'say hello',
#  'see above',
#  'see below',
#  'see below',
#  'seize him',
#  'seize him',
#  'seriously',
#  'seriously',
#  'seriously',
#  'she cried',
#  'she cried',
#  'she tried',
#  'she walks',
#  'she s hot',
#  'she s hot',
#  'sign here',
#  'sign here',
#  'sign this',
#  'sign this',
#  'slow down',
#  'slow down',
#  'stay away',
#  'stay away',
#  'stay back',
#  'stay back',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay down',
#  'stay down',
#  'stay down',
#  'stay down',
#  'stay here',
#  'stay here',
#  'stay here',
#  'stay thin',
#  'step back',
#  'step back',
#  'stop that',
#  'stop that',
#  'stop that',
#  'stop that',
#  'stop them',
#  'take care',
#  'take care',
#  'take care',
#  'take care',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take this',
#  'take this',
#  'thank you',
#  'thank you',
#  'that s ok',
#  'that s ok',
#  'that s ok',
#  'that s ok',
#  'that s it',
#  'then what',
#  'they fell',
#  'they fell',
#  'they left',
#  'they left',
#  'they lied',
#  'they lied',
#  'they lost',
#  'they lost',
#  'they swam',
#  'they swam',
#  'they swam',
#  'they swam',
#  'time s up',
#  'tom cooks',
#  'tom cried',
#  'tom is ok',
#  'tom knits',
#  'tom knows',
#  'tom rocks',
#  'tom spoke',
#  'tom waved',
#  'tom works',
#  'tom s fat',
#  'tom s mad',
#  'tom s mad',
#  'tom s sad',
#  'trust tom',
#  'trust tom',
#  'try again',
#  'try again',
#  'try again',
#  'try it on',
#  'turn left',
#  'wait here',
#  'wait here',
#  'wait here',
#  'wait here',
#  'watch out',
#  'watch out',
#  'watch out',
#  'we agreed',
#  'we did it',
#  'we did it',
#  'we did it',
#  'we forgot',
#  'we saw it',
#  'we saw it',
#  'we smiled',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we waited',
#  'we waited',
#  'we walked',
#  'we walked',
#  'we ll try',
#  'we ll try',
#  'we ll win',
#  'we ll win',
#  'we re hot',
#  'we re sad',
#  ...]

# %%
from nltk.tokenize import sent_tokenize
from gensim.utils import simple_preprocess
words=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))   # Simple Preprcoess make it lowe r case
words
# Out:
# [['hi'],
#  ['run'],
#  ['run'],
#  ['who'],
#  ['wow'],
#  ['fire'],
#  ['help'],
#  ['jump'],
#  ['stop'],
#  ['stop'],
#  ['stop'],
#  ['wait'],
#  ['wait'],
#  ['go', 'on'],
#  ['go', 'on'],
#  ['go', 'on'],
#  ['hello'],
#  ['hello'],
#  ['see'],
#  ['try'],
#  ['won'],
#  ['won'],
#  ['won'],
#  ['oh', 'no'],
#  ['attack'],
#  ['attack'],
#  ['cheers'],
#  ['cheers'],
#  ['cheers'],
#  ['cheers'],
#  ['get', 'up'],
#  ['go', 'now'],
#  ['go', 'now'],
#  ['go', 'now'],
#  ['got', 'it'],
#  ['got', 'it'],
#  ['got', 'it'],
#  ['got', 'it'],
#  ['got', 'it'],
#  ['hop', 'in'],
#  ['hop', 'in'],
#  ['hug', 'me'],
#  ['hug', 'me'],
#  ['fell'],
#  ['fell'],
#  ['know'],
#  ['left'],
#  ['left'],
#  ['lied'],
#  ['lost'],
#  ['paid'],
#  [],
#  ['ok'],
#  ['ok'],
#  ['listen'],
#  ['no', 'way'],
#  ['no', 'way'],
#  ['no', 'way'],
#  ['no', 'way'],
#  ['no', 'way'],
#  ['no', 'way'],
#  ['no', 'way'],
#  ['no', 'way'],
#  ['no', 'way'],
#  ['really'],
#  ['really'],
#  ['really'],
#  ['thanks'],
#  ['we', 'try'],
#  ['we', 'won'],
#  ['we', 'won'],
#  ['we', 'won'],
#  ['we', 'won'],
#  ['ask', 'tom'],
#  ['awesome'],
#  ['be', 'calm'],
#  ['be', 'calm'],
#  ['be', 'calm'],
#  ['be', 'cool'],
#  ['be', 'fair'],
#  ['be', 'fair'],
#  ['be', 'fair'],
#  ['be', 'fair'],
#  ['be', 'fair'],
#  ['be', 'fair'],
#  ['be', 'kind'],
#  ['be', 'nice'],
#  ['be', 'nice'],
#  ['be', 'nice'],
#  ['be', 'nice'],
#  ['be', 'nice'],
#  ['be', 'nice'],
#  ['beat', 'it'],
#  ['call', 'me'],
#  ['call', 'me'],
#  ['call', 'us'],
#  ['call', 'us'],
#  ['come', 'in'],
#  ['come', 'in'],
#  ['come', 'in'],
#  ['come', 'in'],
#  ['come', 'on'],
#  ['come', 'on'],
#  ['come', 'on'],
#  ['come', 'on'],
#  ['drop', 'it'],
#  ['drop', 'it'],
#  ['drop', 'it'],
#  ['drop', 'it'],
#  ['get', 'tom'],
#  ['get', 'out'],
#  ['get', 'out'],
#  ['get', 'out'],
#  ['get', 'out'],
#  ['get', 'out'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'away'],
#  ['go', 'home'],
#  ['go', 'home'],
#  ['go', 'home'],
#  ['go', 'home'],
#  ['go', 'slow'],
#  ['go', 'slow'],
#  ['goodbye'],
#  ['goodbye'],
#  ['hang', 'on'],
#  ['hang', 'on'],
#  ['hang', 'on'],
#  ['hang', 'on'],
#  ['he', 'quit'],
#  ['he', 'quit'],
#  ['he', 'runs'],
#  ['help', 'me'],
#  ['help', 'me'],
#  ['help', 'me'],
#  ['help', 'us'],
#  ['help', 'us'],
#  ['hold', 'it'],
#  ['hold', 'on'],
#  ['hug', 'tom'],
#  ['agree'],
#  ['cried'],
#  ['dozed'],
#  ['dozed'],
#  ['drive'],
#  ['smoke'],
#  ['snore'],
#  ['stink'],
#  ['stood'],
#  ['stood'],
#  ['swore'],
#  ['swore'],
#  ['tried'],
#  ['tried'],
#  ['tried'],
#  ['waved'],
#  ['ll', 'go'],
#  ['tom'],
#  ['fat'],
#  ['fat'],
#  ['fit'],
#  ['hit'],
#  ['hit'],
#  ['ill'],
#  ['sad'],
#  ['shy'],
#  ['wet'],
#  ['wet'],
#  ['it', 'me'],
#  ['join', 'us'],
#  ['join', 'us'],
#  ['keep', 'it'],
#  ['keep', 'it'],
#  ['kiss', 'me'],
#  ['kiss', 'me'],
#  ['me', 'too'],
#  ['open', 'up'],
#  ['open', 'up'],
#  ['perfect'],
#  ['see', 'you'],
#  ['see', 'you'],
#  ['see', 'you'],
#  ['see', 'you'],
#  ['show', 'me'],
#  ['show', 'me'],
#  ['shut', 'up'],
#  ['shut', 'up'],
#  ['shut', 'up'],
#  ['shut', 'up'],
#  ['shut', 'up'],
#  ['skip', 'it'],
#  ['so', 'long'],
#  ['take', 'it'],
#  ['take', 'it'],
#  ['take', 'it'],
#  ['take', 'it'],
#  ['tell', 'me'],
#  ['tell', 'me'],
#  ['tom', 'won'],
#  ['wake', 'up'],
#  ['wake', 'up'],
#  ['wake', 'up'],
#  ['wake', 'up'],
#  ['wake', 'up'],
#  ['wash', 'up'],
#  ['wash', 'up'],
#  ['we', 'know'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['we', 'lost'],
#  ['welcome'],
#  ['who', 'won'],
#  ['who', 'won'],
#  ['you', 'run'],
#  ['am', 'fat'],
#  ['am', 'fat'],
#  ['ask', 'them'],
#  ['ask', 'them'],
#  ['back', 'off'],
#  ['back', 'off'],
#  ['back', 'off'],
#  ['back', 'off'],
#  ['back', 'off'],
#  ['back', 'off'],
#  ['be', 'man'],
#  ['be', 'man'],
#  ['be', 'still'],
#  ['be', 'still'],
#  ['be', 'still'],
#  ['beats', 'me'],
#  ['beats', 'me'],
#  ['call', 'tom'],
#  ['call', 'tom'],
#  ['cheer', 'up'],
#  ['cool', 'off'],
#  ['cuff', 'him'],
#  ['drive', 'on'],
#  ['drive', 'on'],
#  ['drive', 'on'],
#  ['drive', 'on'],
#  ['find', 'tom'],
#  ['find', 'tom'],
#  ['fix', 'this'],
#  ['fix', 'this'],
#  ['get', 'down'],
#  ['get', 'down'],
#  ['get', 'down'],
#  ['get', 'down'],
#  ['get', 'down'],
#  ['get', 'lost'],
#  ['get', 'lost'],
#  ['get', 'lost'],
#  ['get', 'real'],
#  ['go', 'ahead'],
#  ['go', 'ahead'],
#  ['go', 'ahead'],
#  ['go', 'ahead'],
#  ['go', 'ahead'],
#  ['go', 'ahead'],
#  ['go', 'ahead'],
#  ['good', 'job'],
#  ['good', 'job'],
#  ['good', 'job'],
#  ['grab', 'him'],
#  ['grab', 'him'],
#  ['have', 'fun'],
#  ['have', 'fun'],
#  ['he', 'tries'],
#  ['he', 'wet'],
#  ['help', 'tom'],
#  ['help', 'tom'],
#  ['hi', 'guys'],
#  ['how', 'cute'],
#  ['how', 'deep'],
#  ['how', 'nice'],
#  ['how', 'nice'],
#  ['how', 'nice'],
#  ['how', 'nice'],
#  ['hurry', 'up'],
#  ['hurry', 'up'],
#  ['hurry', 'up'],
#  ['hurry', 'up'],
#  ['did', 'ok'],
#  ['did', 'ok'],
#  ['did', 'it'],
#  ['did', 'it'],
#  ['failed'],
#  ['forgot'],
#  ['get', 'it'],
#  ['got', 'it'],
#  ['got', 'it'],
#  ['helped'],
#  ['jumped'],
#  ['looked'],
#  ['moaned'],
#  ['nodded'],
#  ['obeyed'],
#  ['phoned'],
#  ['phoned'],
#  ['refuse'],
#  ['refuse'],
#  ['rested'],
#  ['rested'],
#  ['saw', 'it'],
#  ['saw', 'it'],
#  ['sighed'],
#  ['stayed'],
#  ['stayed'],
#  ['talked'],
#  ['use', 'it'],
#  ['use', 'it'],
#  ['use', 'it'],
#  ['ll', 'pay'],
#  ['ll', 'try'],
#  ['ll', 'try'],
#  ['back'],
#  ['back'],
#  ['bald'],
#  ['busy'],
#  ['busy'],
#  ['calm'],
#  ['cold'],
#  ['cool'],
#  ['cool'],
#  ['deaf'],
#  ['deaf'],
#  ['done'],
#  ['fair'],
#  ['fair'],
#  ['fair'],
#  ['fast'],
#  ['fine'],
#  ['fine'],
#  ['fine'],
#  ['free'],
#  ['free'],
#  ['free'],
#  ['full'],
#  ['full'],
#  ['game'],
#  ['game'],
#  ['glad'],
#  ['home'],
#  ['late'],
#  ['lazy'],
#  ['lazy'],
#  ['lazy'],
#  ['lazy'],
#  ['okay'],
#  ['okay'],
#  ['rich'],
#  ['safe'],
#  ['sick'],
#  ['sure'],
#  ['sure'],
#  ['sure'],
#  ['sure'],
#  ['tall'],
#  ['thin'],
#  ['tidy'],
#  ['tidy'],
#  ['ugly'],
#  ['ugly'],
#  ['weak'],
#  ['well'],
#  ['well'],
#  ['ve', 'won'],
#  ['ve', 'won'],
#  ['it', 'helps'],
#  ['it', 'hurts'],
#  ['it', 'works'],
#  ['it', 'works'],
#  ['it', 'tom'],
#  ['it', 'fun'],
#  ['it', 'fun'],
#  ['it', 'his'],
#  ['it', 'his'],
#  ['it', 'new'],
#  ['it', 'new'],
#  ['it', 'odd'],
#  ['it', 'red'],
#  ['it', 'sad'],
#  ['keep', 'out'],
#  ['keep', 'out'],
#  ['kiss', 'tom'],
#  ['leave', 'it'],
#  ['leave', 'it'],
#  ['leave', 'me'],
#  ['leave', 'us'],
#  ['leave', 'us'],
#  ['let', 'go'],
#  ['let', 'go'],
#  ['look', 'out'],
#  ['look', 'out'],
#  ['marry', 'me'],
#  ['marry', 'me'],
#  ['may', 'go'],
#  ['may', 'go'],
#  ['may', 'go'],
#  ['save', 'tom'],
#  ['save', 'tom'],
#  ['say', 'what'],
#  ['she', 'came'],
#  ['she', 'died'],
#  ['she', 'runs'],
#  ['sit', 'down'],
#  ['sit', 'down'],
#  ['sit', 'down'],
#  ['sit', 'here'],
#  ['sit', 'here'],
#  ['speak', 'up'],
#  ['speak', 'up'],
#  ['stand', 'up'],
#  ['stop', 'tom'],
#  ['stop', 'tom'],
#  ['taste', 'it'],
#  ['taste', 'it'],
#  ['taste', 'it'],
#  ['taste', 'it'],
#  ['tell', 'tom'],
#  ['tell', 'tom'],
#  ['terrific'],
#  ['terrific'],
#  ['terrific'],
#  ['they', 'won'],
#  ['they', 'won'],
#  ['they', 'won'],
#  ['they', 'won'],
#  ['tom', 'came'],
#  ['tom', 'died'],
#  ['tom', 'knew'],
#  ['tom', 'left'],
#  ['tom', 'left'],
#  ['tom', 'lied'],
#  ['tom', 'lies'],
#  ['tom', 'lost'],
#  ['tom', 'paid'],
#  ['too', 'late'],
#  ['trust', 'me'],
#  ['trust', 'me'],
#  ['try', 'hard'],
#  ['try', 'some'],
#  ['try', 'some'],
#  ['try', 'this'],
#  ['try', 'this'],
#  ['use', 'this'],
#  ['use', 'this'],
#  ['use', 'this'],
#  ['use', 'this'],
#  ['warn', 'tom'],
#  ['warn', 'tom'],
#  ['watch', 'me'],
#  ['watch', 'me'],
#  ['watch', 'us'],
#  ['watch', 'us'],
#  ['we', 'agree'],
#  ['we', 'll', 'go'],
#  ['we', 're', 'ok'],
#  ['what', 'for'],
#  ['what', 'for'],
#  ['what', 'fun'],
#  ['what', 'fun'],
#  ['who', 'came'],
#  ['who', 'died'],
#  ['who', 'fell'],
#  ['who', 'quit'],
#  ['who', 'he'],
#  ['write', 'me'],
#  ['write', 'me'],
#  ['you', 'lost'],
#  ['you', 'lost'],
#  ['after', 'you'],
#  ['aim', 'fire'],
#  ['am', 'late'],
#  ['answer', 'me'],
#  ['be', 'seated'],
#  ['be', 'seated'],
#  ['birds', 'fly'],
#  ['bless', 'you'],
#  ['call', 'home'],
#  ['calm', 'down'],
#  ['calm', 'down'],
#  ['can', 'we', 'go'],
#  ['can', 'we', 'go'],
#  ['can', 'we', 'go'],
#  ['catch', 'tom'],
#  ['catch', 'tom'],
#  ['catch', 'him'],
#  ['chill', 'out'],
#  ['come', 'back'],
#  ['come', 'back'],
#  ['come', 'here'],
#  ['come', 'here'],
#  ['come', 'over'],
#  ['come', 'over'],
#  ['come', 'over'],
#  ['come', 'over'],
#  ['come', 'over'],
#  ['come', 'over'],
#  ['come', 'over'],
#  ['come', 'soon'],
#  ['come', 'soon'],
#  ['cool', 'down'],
#  ['did', 'win'],
#  ['did', 'win'],
#  ['did', 'win'],
#  ['do', 'it', 'now'],
#  ['dogs', 'bark'],
#  ['dogs', 'bark'],
#  ['don', 'ask'],
#  ['don', 'cry'],
#  ['don', 'die'],
#  ['don', 'die'],
#  ['don', 'lie'],
#  ['don', 'run'],
#  ['don', 'run'],
#  ['excuse', 'me'],
#  ['excuse', 'me'],
#  ['excuse', 'me'],
#  ['excuse', 'me'],
#  ['excuse', 'me'],
#  ['excuse', 'me'],
#  ['excuse', 'me'],
#  ['fantastic'],
#  ['feel', 'this'],
#  ['feel', 'this'],
#  ['feel', 'this'],
#  ['feel', 'this'],
#  ['follow', 'me'],
#  ['follow', 'us'],
#  ['follow', 'us'],
#  ['forget', 'it'],
#  ['forget', 'it'],
#  ['forget', 'it'],
#  ['forget', 'it'],
#  ['forget', 'it'],
#  ['forget', 'it'],
#  ['forget', 'it'],
#  ['get', 'job'],
#  ['get', 'job'],
#  ['get', 'job'],
#  ['get', 'job'],
#  ['get', 'ready'],
#  ['get', 'ready'],
#  ['go', 'get', 'it'],
#  ['go', 'get', 'it'],
#  ['go', 'inside'],
#  ['go', 'to', 'bed'],
#  ['go', 'to', 'bed'],
#  ['good', 'luck'],
#  ['good', 'luck'],
#  ['grab', 'that'],
#  ['grab', 'that'],
#  ['grab', 'that'],
#  ['grab', 'that'],
#  ['grab', 'this'],
#  ['grab', 'this'],
#  ['hands', 'off'],
#  ['he', 'is', 'ill'],
#  ['he', 'is', 'old'],
#  ['he', 'dj'],
#  ['he', 'good'],
#  ['he', 'lazy'],
#  ['he', 'mine'],
#  ['he', 'rich'],
#  ['he', 'sexy'],
#  ['here', 'am'],
#  ['here'],
#  ['hold', 'fire'],
#  ['hold', 'fire'],
#  ['hold', 'this'],
#  ['hold', 'this'],
#  ['hold', 'this'],
#  ['hold', 'this'],
#  ['how', 'awful'],
#  ['how', 'weird'],
#  ['how', 'tom'],
#  ['how', 'tom'],
#  ['am', 'cold'],
#  ['am', 'good'],
#  ['am', 'okay'],
#  ['am', 'sick'],
#  ['am', 'sure'],
#  ['am', 'sure'],
#  ['beg', 'you'],
#  ['beg', 'you'],
#  ['beg', 'you'],
#  ['beg', 'you'],
#  ['can', 'run'],
#  ['can', 'ski'],
#  ['cringed'],
#  ['cringed'],
#  ['cringed'],
#  ['exhaled'],
#  ['gave', 'up'],
#  ['give', 'in'],
#  ['give', 'up'],
#  ['got', 'hot'],
#  ['got', 'hot'],
#  ['had', 'fun'],
#  ['had', 'fun'],
#  ['had', 'fun'],
#  ['had', 'fun'],
#  ['hate', 'it'],
#  ['have', 'it'],
#  ['hit', 'tom'],
#  ['hope', 'so'],
#  ['hurried'],
#  ['hurried'],
#  ['inhaled'],
#  ['knew', 'it'],
#  ['like', 'it'],
#  ['lost', 'it'],
#  ['love', 'it'],
#  ['love', 'it'],
#  ['mean', 'it'],
#  ['mean', 'it'],
#  ['must', 'go'],
#  ['must', 'go'],
#  ['must', 'go'],
#  ['must', 'go'],
#  ['must', 'go'],
#  ['must', 'go'],
#  ['must', 'go'],
#  ['must', 'go'],
#  ['need', 'it'],
#  ['need', 'it'],
#  ['noticed'],
#  ['prepaid'],
#  ['promise'],
#  ['relaxed'],
#  ['relaxed'],
#  ['retired'],
#  ['said', 'no'],
#  ['said', 'so'],
#  ['saw', 'him'],
#  ['saw', 'him'],
#  ['saw', 'him'],
#  ['saw', 'one'],
#  ['saw', 'one'],
#  ['saw', 'you'],
#  ['saw', 'you'],
#  ['saw', 'you'],
#  ['saw', 'you'],
#  ['saw', 'you'],
#  ['saw', 'you'],
#  ['saw', 'you'],
#  ['saw', 'you'],
#  ['see', 'tom'],
#  ['shouted'],
#  ['tripped'],
#  ['tripped'],
#  ['want', 'it'],
#  ['was', 'new'],
#  ['was', 'new'],
#  ['will', 'go'],
#  ['woke', 'up'],
#  ['woke', 'up'],
#  ['agree'],
#  ['leave'],
#  ['ll', 'call'],
#  ['ll', 'cook'],
#  ['ll', 'help'],
#  ['ll', 'live'],
#  ['ll', 'obey'],
#  ['ll', 'pack'],
#  ['ll', 'pack'],
#  ['ll', 'pack'],
#  ['ll', 'pass'],
#  ['ll', 'quit'],
#  ['ll', 'sing'],
#  ['ll', 'stop'],
#  ['ll', 'swim'],
#  ['ll', 'talk'],
#  ['ll', 'talk'],
#  ['ll', 'wait'],
#  ['ll', 'walk'],
#  ['ll', 'work'],
#  ['ll', 'work'],
#  ['cop'],
#  ['man'],
#  ['alive'],
#  ['alive'],
#  ['alive'],
#  ['alone'],
#  ['alone'],
#  ['angry'],
#  ['angry'],
#  ['armed'],
#  ['armed'],
#  ['awake'],
#  ['blind'],
#  ['broke'],
#  ['clean'],
#  ['clean'],
#  ['crazy'],
#  ['crazy'],
#  ['cured'],
#  ['cured'],
#  ['dizzy'],
#  ['drunk'],
#  ['drunk'],
#  ['drunk'],
#  ['dying'],
#  ['early'],
#  ['first'],
#  ['fussy'],
#  ['fussy'],
#  ['fussy'],
#  ['going'],
#  ['going'],
#  ['going'],
#  ['going'],
#  ['loyal'],
#  ['loyal'],
#  ['lucky'],
#  ['lucky'],
#  ['lucky'],
#  ['lucky'],
#  ['lucky'],
#  ['lying'],
#  ['naked'],
#  ['naked'],
#  ['naked'],
#  ['naked'],
#  ['naked'],
#  ['quiet'],
#  ['ready'],
#  ['ready'],
#  ['ready'],
#  ['right'],
#  ['sober'],
#  ['sorry'],
#  ['sorry'],
#  ['sorry'],
#  ['sorry'],
#  ['sorry'],
#  ['sorry'],
#  ['stuck'],
#  ['timid'],
#  ['tired'],
#  ['tough'],
#  ['tough'],
#  ['tough'],
#  ['tough'],
#  ['yours'],
#  ['yours'],
#  ['ve', 'lost'],
#  ['is', 'tom', 'ok'],
#  ['is', 'tom', 'ok'],
#  ['is', 'it', 'bad'],
#  ['is', 'it', 'far'],
#  ['is', 'it', 'far'],
#  ['is', 'it', 'hot'],
#  ['is', 'it', 'you'],
#  ['is', 'it', 'you'],
#  ['is', 'it', 'you'],
#  ['it', 'failed'],
#  ['it', 'snowed'],
#  ['it', 'stinks'],
#  ['it', 'stinks'],
#  ['it', 'was', 'ok'],
#  ['it', 'was', 'ok'],
#  ['it', 'was', 'ok'],
#  ['it', 'worked'],
#  ['it', 'worked'],
#  ['it'],
#  ['it'],
#  ['it'],
#  ['it', 'tv'],
#  ['it', 'cold'],
#  ['it', 'cold'],
#  ['it', 'dark'],
#  ['it', 'dead'],
#  ['it', 'dead'],
#  ['it', 'dead'],
#  ['it', 'done'],
#  ['it', 'easy'],
#  ['it', 'food'],
#  ['it', 'free'],
#  ['it', 'here'],
#  ['it', 'here'],
#  ['it', 'hers'],
#  ['it', 'hers'],
#  ['it', 'late'],
#  ['it', 'lost'],
#  ['it', 'mine'],
#  ['it', 'mine'],
#  ['it', 'mine'],
#  ['it', 'mine'],
#  ['it', 'open'],
#  ['it', 'ours'],
#  ['it', 'ours'],
#  ['it', 'ours'],
#  ['it', 'sand'],
#  ['it', 'time'],
#  ['it', 'time'],
#  ['it', 'true'],
#  ['it', 'work'],
#  ['keep', 'calm'],
#  ['keep', 'that'],
#  ['keep', 'that'],
#  ['keep', 'this'],
#  ['keep', 'this'],
#  ['let', 'it', 'be'],
#  ['let', 'it', 'be'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'go'],
#  ['let', 'me', 'in'],
#  ['let', 'me', 'in'],
#  ['let', 'ask'],
#  ['let', 'eat'],
#  ['let', 'see'],
#  ['lie', 'still'],
#  ['lie', 'still'],
#  ['lie', 'still'],
#  ['lie', 'still'],
#  ['lie', 'still'],
#  ['lie', 'still'],
#  ['look', 'away'],
#  ['look', 'away'],
#  ['look', 'back'],
#  ['look', 'back'],
#  ['look', 'here'],
#  ['look', 'here'],
#  ['loosen', 'up'],
#  ['loosen', 'up'],
#  ['loosen', 'up'],
#  ['loosen', 'up'],
#  ['loosen', 'up'],
#  ['move', 'over'],
#  ['move', 'over'],
#  ['move', 'over'],
#  ['nice', 'shot'],
#  ['of', 'course'],
#  ['of', 'course'],
#  ['of', 'course'],
#  ['of', 'course'],
#  ['of', 'course'],
#  ['oh', 'please'],
#  ['oh', 'please'],
#  ['pardon', 'me'],
#  ['pardon', 'me'],
#  ['pardon', 'me'],
#  ['read', 'this'],
#  ['say', 'hello'],
#  ['see', 'above'],
#  ['see', 'below'],
#  ['see', 'below'],
#  ['seize', 'him'],
#  ['seize', 'him'],
#  ['seriously'],
#  ['seriously'],
#  ['seriously'],
#  ['she', 'cried'],
#  ['she', 'cried'],
#  ['she', 'tried'],
#  ['she', 'walks'],
#  ['she', 'hot'],
#  ['she', 'hot'],
#  ['sign', 'here'],
#  ['sign', 'here'],
#  ['sign', 'this'],
#  ['sign', 'this'],
#  ['slow', 'down'],
#  ['slow', 'down'],
#  ['stay', 'away'],
#  ['stay', 'away'],
#  ['stay', 'back'],
#  ['stay', 'back'],
#  ['stay', 'calm'],
#  ['stay', 'calm'],
#  ['stay', 'calm'],
#  ['stay', 'calm'],
#  ['stay', 'calm'],
#  ['stay', 'down'],
#  ['stay', 'down'],
#  ['stay', 'down'],
#  ['stay', 'down'],
#  ['stay', 'here'],
#  ['stay', 'here'],
#  ['stay', 'here'],
#  ['stay', 'thin'],
#  ['step', 'back'],
#  ['step', 'back'],
#  ['stop', 'that'],
#  ['stop', 'that'],
#  ['stop', 'that'],
#  ['stop', 'that'],
#  ['stop', 'them'],
#  ['take', 'care'],
#  ['take', 'care'],
#  ['take', 'care'],
#  ['take', 'care'],
#  ['take', 'mine'],
#  ['take', 'mine'],
#  ['take', 'mine'],
#  ['take', 'mine'],
#  ['take', 'mine'],
#  ['take', 'mine'],
#  ['take', 'mine'],
#  ['take', 'mine'],
#  ['take', 'this'],
#  ['take', 'this'],
#  ['thank', 'you'],
#  ['thank', 'you'],
#  ['that', 'ok'],
#  ['that', 'ok'],
#  ['that', 'ok'],
#  ['that', 'ok'],
#  ['that', 'it'],
#  ['then', 'what'],
#  ['they', 'fell'],
#  ['they', 'fell'],
#  ['they', 'left'],
#  ['they', 'left'],
#  ['they', 'lied'],
#  ['they', 'lied'],
#  ['they', 'lost'],
#  ['they', 'lost'],
#  ['they', 'swam'],
#  ['they', 'swam'],
#  ['they', 'swam'],
#  ['they', 'swam'],
#  ['time', 'up'],
#  ['tom', 'cooks'],
#  ['tom', 'cried'],
#  ['tom', 'is', 'ok'],
#  ['tom', 'knits'],
#  ['tom', 'knows'],
#  ['tom', 'rocks'],
#  ['tom', 'spoke'],
#  ['tom', 'waved'],
#  ['tom', 'works'],
#  ['tom', 'fat'],
#  ['tom', 'mad'],
#  ['tom', 'mad'],
#  ['tom', 'sad'],
#  ['trust', 'tom'],
#  ['trust', 'tom'],
#  ['try', 'again'],
#  ['try', 'again'],
#  ['try', 'again'],
#  ['try', 'it', 'on'],
#  ['turn', 'left'],
#  ['wait', 'here'],
#  ['wait', 'here'],
#  ['wait', 'here'],
#  ['wait', 'here'],
#  ['watch', 'out'],
#  ['watch', 'out'],
#  ['watch', 'out'],
#  ['we', 'agreed'],
#  ['we', 'did', 'it'],
#  ['we', 'did', 'it'],
#  ['we', 'did', 'it'],
#  ['we', 'forgot'],
#  ['we', 'saw', 'it'],
#  ['we', 'saw', 'it'],
#  ['we', 'smiled'],
#  ['we', 'talked'],
#  ['we', 'talked'],
#  ['we', 'talked'],
#  ['we', 'talked'],
#  ['we', 'talked'],
#  ['we', 'waited'],
#  ['we', 'waited'],
#  ['we', 'walked'],
#  ['we', 'walked'],
#  ['we', 'll', 'try'],
#  ['we', 'll', 'try'],
#  ['we', 'll', 'win'],
#  ['we', 'll', 'win'],
#  ['we', 're', 'hot'],
#  ['we', 're', 'sad'],
#  ...]

# %%
all_words = [word for sentence in words for word in sentence]

# Get unique words
unique_words_input = set(all_words)

# Count them
print("Number of unique words:", len(unique_words_input))
print("Unique words:", unique_words_input)
# Out:
# Number of unique words: 1204
# Unique words: {'overslept', 'miss', 'bossy', 'told', 'lawyer', 'follow', 'what', 'duty', 'shocked', 'in', 'ears', 'kids', 'calls', 'team', 'blessed', 'vote', 'quick', 'pig', 'glue', 'wasn', 'poison', 'lies', 'free', 'likes', 'sure', 'thirsty', 'music', 'say', 'fear', 'friend', 'thin', 'take', 'upset', 'frantic', 'date', 'where', 'lying', 'great', 'bath', 'grateful', 'cheat', 'talking', 'sing', 'my', 'set', 'starving', 'hip', 'woman', 'amuse', 'drowned', 'doll', 'avoids', 'skate', 'accept', 'reformed', 'while', 'lazy', 'jerk', 'eating', 'song', 'immune', 'falling', 'cloudy', 'grab', 'well', 'married', 'exhaled', 'cover', 'psychic', 'hit', 'fruit', 'hand', 'handled', 'clear', 'bet', 'shadow', 'hero', 'happens', 'even', 'gloat', 'brave', 'heard', 'honey', 'favor', 'flat', 'long', 'hot', 'hurry', 'shot', 'admit', 'think', 'warm', 'me', 'sec', 'dancing', 'cat', 'sweated', 'above', 'sick', 'trips', 'pick', 'reliable', 'smoking', 'had', 'fret', 'stand', 'hug', 'too', 'single', 'boys', 'snow', 'cds', 'see', 'approved', 'cultured', 'said', 'risks', 'shooting', 'listen', 'idiot', 'evening', 'called', 'warn', 'by', 'at', 'came', 'bother', 'gas', 'fantastic', 'canceled', 'rational', 'thrilled', 'shock', 'books', 'refuse', 'ironic', 'needed', 'send', 'open', 'silly', 'thought', 'paid', 'cheats', 'warmer', 'tight', 'agreed', 'no', 'aboard', 'trapped', 'stinks', 'move', 'shouted', 'tall', 'time', 'twice', 'adult', 'meat', 'recess', 'fox', 'listened', 'looking', 'nerve', 'with', 'ain', 'went', 'shrieked', 'fell', 'card', 'questions', 'room', 'screamed', 'cringed', 'safely', 'believe', 'down', 'yawned', 'teach', 'grounded', 'asked', 'things', 'never', 'walk', 'blow', 'hang', 'bread', 'lunch', 'closed', 'fool', 'could', 'forward', 'absurd', 'rice', 'flip', 'seize', 're', 'fast', 'sexy', 'again', 'matters', 'jokes', 'hungover', 'selfish', 'confident', 'broken', 'bigot', 'rain', 'die', 'approves', 'sue', 'quit', 'loyal', 'cab', 'dancer', 'found', 'hurt', 'smashed', 'man', 'panic', 'calm', 'stay', 'awesome', 'moody', 'merciful', 'nobody', 'garbage', 'laughed', 'noticed', 'two', 'poor', 'dance', 'perfect', 'priest', 'out', 'gullible', 'baking', 'outraged', 'inhaled', 'full', 'dozed', 'ours', 'cool', 'come', 'excuse', 'lighten', 'bless', 'idea', 'closely', 'wow', 'sent', 'bleeding', 'busy', 'inside', 'map', 'dreaming', 'fun', 'armed', 'trying', 'caught', 'dizzy', 'recovered', 'third', 'involved', 'member', 'mine', 'iron', 'beat', 'doomed', 'love', 'awake', 'war', 'act', 'may', 'rocks', 'walked', 'nasty', 'cared', 'bite', 'dare', 'cursed', 'sushi', 'dream', 'sorry', 'ill', 'let', 'turn', 'help', 'scare', 'helps', 'best', 'icky', 'mess', 'comment', 'good', 'yelled', 'nothing', 'boss', 'chuckled', 'home', 'cheers', 'look', 'eyes', 'dig', 'wept', 'jobs', 'ghosts', 'dirty', 'teasing', 'serious', 'dogs', 'sign', 'drives', 'squinted', 'money', 'girls', 'correct', 'heal', 'mean', 'snowing', 'them', 'sued', 'monk', 'talk', 'chill', 'decide', 'crime', 'messed', 'more', 'warned', 'we', 'can', 'dump', 'nice', 'away', 'resigned', 'list', 'positive', 'were', 'smiled', 'starve', 'marry', 'trust', 'write', 'hello', 'leaving', 'tired', 'answer', 'next', 'fined', 'mad', 'cruel', 'moved', 'gross', 'lonely', 'safer', 'far', 'waved', 'black', 'welcome', 'fired', 'bored', 'so', 'make', 'lion', 'break', 'now', 'soup', 'felt', 'fat', 'wrote', 'cancel', 'is', 'start', 'ignore', 'starved', 'dumb', 'hives', 'whiff', 'stoned', 'happen', 'car', 'obey', 'running', 'nailed', 'tripped', 'stuck', 'litter', 'baker', 'spring', 'sleeping', 'flies', 'careful', 'need', 'wise', 'pregnant', 'runs', 'yours', 'silent', 'caviar', 'woke', 'loaded', 'sweet', 'dark', 'drank', 'goes', 'fill', 'mary', 'rifle', 'broke', 'faster', 'rested', 'live', 'moving', 'joke', 'cold', 'bed', 'shall', 'heel', 'beware', 'cheated', 'unlucky', 'beats', 'rich', 'cash', 'plans', 'wolf', 'check', 'back', 'wonderful', 'apples', 'complex', 'faithful', 'strong', 'needs', 'buried', 'who', 'seriously', 'begin', 'just', ' ...

# %%
max_len_input = max(len(sentence) for sentence in words)
longest_sentence = max(words, key=len)

print("Max number of words:", max_len_input)
print("Sentence with max words:", longest_sentence)
# Out:
# Max number of words: 4
# Sentence with max words: ['is', 'it', 'to', 'go']

# %% [markdown]
# ## Input Encoding:

# %%
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
one_hot_input=[one_hot(word, len(unique_words_input)) for word in corpus]
one_hot_input
# Out:
# [[439],
#  [378],
#  [378],
#  [878],
#  [738],
#  [210],
#  [1001],
#  [549],
#  [1180],
#  [1180],
#  [1180],
#  [1123],
#  [1123],
#  [109, 453],
#  [109, 453],
#  [109, 453],
#  [945],
#  [945],
#  [189, 778],
#  [189, 118],
#  [189, 462],
#  [189, 462],
#  [189, 462],
#  [225, 1137],
#  [539],
#  [539],
#  [837],
#  [837],
#  [837],
#  [837],
#  [878, 1080],
#  [109, 1162],
#  [109, 1162],
#  [109, 1162],
#  [274, 508],
#  [274, 508],
#  [274, 508],
#  [274, 508],
#  [274, 508],
#  [1051, 664],
#  [1051, 664],
#  [431, 171],
#  [431, 171],
#  [189, 970],
#  [189, 970],
#  [189, 755],
#  [189, 701],
#  [189, 701],
#  [189, 1003],
#  [189, 734],
#  [189, 93],
#  [189, 1125, 892],
#  [189, 1125, 906],
#  [189, 1125, 906],
#  [578],
#  [1137, 328],
#  [1137, 328],
#  [1137, 328],
#  [1137, 328],
#  [1137, 328],
#  [1137, 328],
#  [1137, 328],
#  [1137, 328],
#  [1137, 328],
#  [940],
#  [940],
#  [940],
#  [247],
#  [972, 118],
#  [972, 462],
#  [972, 462],
#  [972, 462],
#  [972, 462],
#  [709, 446],
#  [907],
#  [1086, 764],
#  [1086, 764],
#  [1086, 764],
#  [1086, 426],
#  [1086, 1002],
#  [1086, 1002],
#  [1086, 1002],
#  [1086, 1002],
#  [1086, 1002],
#  [1086, 1002],
#  [1086, 459],
#  [1086, 619],
#  [1086, 619],
#  [1086, 619],
#  [1086, 619],
#  [1086, 619],
#  [1086, 619],
#  [967, 508],
#  [636, 171],
#  [636, 171],
#  [636, 872],
#  [636, 872],
#  [404, 664],
#  [404, 664],
#  [404, 664],
#  [404, 664],
#  [404, 453],
#  [404, 453],
#  [404, 453],
#  [404, 453],
#  [413, 508],
#  [413, 508],
#  [413, 508],
#  [413, 508],
#  [878, 446],
#  [890, 701],
#  [1123, 866],
#  [1123, 866],
#  [1123, 866],
#  [1123, 866],
#  [1141, 248],
#  [1141, 248],
#  [1141, 248],
#  [972, 126],
#  [972, 20, 508],
#  [972, 20, 508],
#  [972, 20, 508],
#  [972, 893],
#  [972, 978, 508],
#  [972, 978, 508],
#  [972, 242],
#  [972, 910],
#  [972, 910],
#  [972, 910],
#  [972, 910],
#  [972, 910],
#  [972, 773],
#  [972, 773],
#  [972, 385],
#  [972, 385],
#  [972, 508, 118],
#  [972, 508, 118],
#  [972, 508, 184],
#  [972, 508, 184],
#  [972, 598, 300],
#  [972, 598, 791],
#  ...]

# %%
input_padding=pad_sequences(one_hot_input, maxlen=max_len_input, padding='post')
input_padding
# Out:
# array([[ 439,    0,    0,    0],
#        [ 378,    0,    0,    0],
#        [ 378,    0,    0,    0],
#        ...,
#        [ 222,  660, 1086, 1006],
#        [ 222,  660,  636,  171],
#        [ 222,  660, 1141,  508]], dtype=int32)

# %% [markdown]
# # Output Preprocessing

# %%
corpus1 = []
for i in range(0, len(dataset)):
    review = re.sub('[^a-zA-Z0-9]', ' ', dataset['French'][i])
    review = review.lower()
    review = review.split()

    review = ' '.join(review)
    corpus1.append(review)

# %%
decoder_input_data = ["<start> " + txt + "" for txt in corpus1]
decoder_target_data= ["" + txt + " <end>" for txt in corpus1]
decoder_input_data
# Out:
# ['<start> salut',
#  '<start> cours',
#  '<start> courez',
#  '<start> qui',
#  '<start> a alors',
#  '<start> au feu',
#  '<start> l aide',
#  '<start> saute',
#  '<start> a suffit',
#  '<start> stop',
#  '<start> arr te toi',
#  '<start> attends',
#  '<start> attendez',
#  '<start> poursuis',
#  '<start> continuez',
#  '<start> poursuivez',
#  '<start> bonjour',
#  '<start> salut',
#  '<start> je comprends',
#  '<start> j essaye',
#  '<start> j ai gagn',
#  '<start> je l ai emport',
#  '<start> j ai gagn',
#  '<start> oh non',
#  '<start> attaque',
#  '<start> attaquez',
#  '<start> sant',
#  '<start> votre sant',
#  '<start> merci',
#  '<start> tchin tchin',
#  '<start> l ve toi',
#  '<start> va maintenant',
#  '<start> allez y maintenant',
#  '<start> vas y maintenant',
#  '<start> j ai pig',
#  '<start> compris',
#  '<start> pig',
#  '<start> compris',
#  '<start> t as capt',
#  '<start> monte',
#  '<start> montez',
#  '<start> serre moi dans tes bras',
#  '<start> serrez moi dans vos bras',
#  '<start> je suis tomb e',
#  '<start> je suis tomb',
#  '<start> je sais',
#  '<start> je suis parti',
#  '<start> je suis partie',
#  '<start> j ai menti',
#  '<start> j ai perdu',
#  '<start> j ai pay',
#  '<start> j ai 19 ans',
#  '<start> je vais bien',
#  '<start> a va',
#  '<start> coutez',
#  '<start> c est pas possible',
#  '<start> impossible',
#  '<start> en aucun cas',
#  '<start> sans fa ons',
#  '<start> c est hors de question',
#  '<start> il n en est pas question',
#  '<start> c est exclu',
#  '<start> en aucune mani re',
#  '<start> hors de question',
#  '<start> vraiment',
#  '<start> vrai',
#  '<start> ah bon',
#  '<start> merci',
#  '<start> on essaye',
#  '<start> nous avons gagn',
#  '<start> nous gagn mes',
#  '<start> nous l avons emport',
#  '<start> nous l emport mes',
#  '<start> demande tom',
#  '<start> fantastique',
#  '<start> sois calme',
#  '<start> soyez calme',
#  '<start> soyez calmes',
#  '<start> sois d tendu',
#  '<start> sois juste',
#  '<start> soyez juste',
#  '<start> soyez justes',
#  '<start> sois quitable',
#  '<start> soyez quitable',
#  '<start> soyez quitables',
#  '<start> sois gentil',
#  '<start> sois gentil',
#  '<start> sois gentille',
#  '<start> soyez gentil',
#  '<start> soyez gentille',
#  '<start> soyez gentils',
#  '<start> soyez gentilles',
#  '<start> d gage',
#  '<start> appelle moi',
#  '<start> appellez moi',
#  '<start> appelle nous',
#  '<start> appelez nous',
#  '<start> entrez',
#  '<start> entre',
#  '<start> entre',
#  '<start> entrez',
#  '<start> allez',
#  '<start> allez',
#  '<start> viens',
#  '<start> venez',
#  '<start> laisse tomber',
#  '<start> laissez tomber',
#  '<start> laisse le tomber',
#  '<start> laissez le tomber',
#  '<start> va chercher tom',
#  '<start> sortez',
#  '<start> sors',
#  '<start> sortez',
#  '<start> sors',
#  '<start> casse toi',
#  '<start> d gage',
#  '<start> pars',
#  '<start> va te faire foutre',
#  '<start> pars',
#  '<start> d gage',
#  '<start> fous le camp',
#  '<start> pars d ici',
#  '<start> va t en',
#  '<start> disparais',
#  '<start> allez vous en',
#  '<start> rentrez la maison',
#  '<start> rentre la maison',
#  '<start> rentre chez toi',
#  '<start> rentrez chez vous',
#  '<start> va doucement',
#  '<start> allez doucement',
#  '<start> adieu',
#  '<start> la revoyure',
#  '<start> attends un peu',
#  '<start> attendez un peu',
#  '<start> tiens bon',
#  '<start> tenez bon',
#  '<start> il laissa tomber',
#  '<start> il a laiss tomber',
#  '<start> il court',
#  '<start> aide moi',
#  '<start> aide moi',
#  '<start> aidez moi',
#  '<start> aidez nous',
#  '<start> aide nous',
#  '<start> ne bouge plus',
#  '<start> ne quittez pas',
#  '<start> fais un c lin tom',
#  '<start> je suis du m me avis',
#  '<start> j ai pleur',
#  '<start> je me suis assoupi',
#  '<start> je me suis assoupie',
#  '<start> je conduis',
#  '<start> je fume',
#  '<start> je ronfle',
#  '<start> je pue',
#  '<start> je me suis tenu debout',
#  '<start> je me suis tenue debout',
#  '<start> j ai promis',
#  '<start> j ai jur',
#  '<start> j essayai',
#  '<start> j ai essay',
#  '<start> j ai tent',
#  '<start> j ai fait signe',
#  '<start> j irai',
#  '<start> je suis tom',
#  '<start> je suis gras',
#  '<start> je suis gros',
#  '<start> je suis en forme',
#  '<start> je suis touch',
#  '<start> je suis touch e',
#  '<start> je suis malade',
#  '<start> je suis triste',
#  '<start> je suis timide',
#  '<start> je suis mouill',
#  '<start> je suis mouill e',
#  '<start> c est bibi',
#  '<start> joignez vous',
#  '<start> joignez vous nous',
#  '<start> garde le',
#  '<start> gardez le',
#  '<start> embrasse moi',
#  '<start> embrassez moi',
#  '<start> moi aussi',
#  '<start> ouvre moi',
#  '<start> ouvre',
#  '<start> parfait',
#  '<start> plus tard',
#  '<start> bient t',
#  '<start> la prochaine',
#  '<start> plus',
#  '<start> montre moi',
#  '<start> montrez moi',
#  '<start> taisez vous',
#  '<start> ferme la',
#  '<start> tais toi',
#  '<start> ferme la',
#  '<start> la ferme',
#  '<start> pas grave',
#  '<start> plus tard',
#  '<start> prends le',
#  '<start> prenez le',
#  '<start> prends le',
#  '<start> prenez le',
#  '<start> dis moi',
#  '<start> dites moi',
#  '<start> tom a gagn',
#  '<start> r veille toi',
#  '<start> r veille toi',
#  '<start> r veillez vous',
#  '<start> r veille toi',
#  '<start> r veillez vous',
#  '<start> lave toi',
#  '<start> lavez vous',
#  '<start> nous savons',
#  '<start> nous perd mes',
#  '<start> nous avons perdu',
#  '<start> nous f mes battus',
#  '<start> nous f mes battues',
#  '<start> nous f mes d faits',
#  '<start> nous f mes d faites',
#  '<start> nous avons t d faits',
#  '<start> nous avons t d faites',
#  '<start> nous avons t battus',
#  '<start> nous avons t battues',
#  '<start> bienvenue',
#  '<start> qui a gagn',
#  '<start> qui l a emport',
#  '<start> tu cours',
#  '<start> suis je gros',
#  '<start> suis je grosse',
#  '<start> demande leur',
#  '<start> demandez leur',
#  '<start> recule',
#  '<start> reculez',
#  '<start> recule',
#  '<start> reculez',
#  '<start> retire toi',
#  '<start> retirez vous',
#  '<start> sois un homme',
#  '<start> soyez un homme',
#  '<start> sois calme',
#  '<start> soyez calme',
#  '<start> soyez calmes',
#  '<start> aucune id e',
#  '<start> j en sais foutre rien',
#  '<start> appelle tom',
#  '<start> appelez tom',
#  '<start> courage',
#  '<start> d tends toi',
#  '<start> menottez le',
#  '<start> avance',
#  '<start> avancez',
#  '<start> continue rouler',
#  '<start> continuez rouler',
#  '<start> trouve tom',
#  '<start> trouvez tom',
#  '<start> r parez ceci',
#  '<start> r pare a',
#  '<start> l che toi',
#  '<start> descends',
#  '<start> descendez',
#  '<start> l che toi',
#  '<start> l chez vous',
#  '<start> va voir ailleurs si j y suis',
#  '<start> d gage',
#  '<start> va au diable',
#  '<start> sois r aliste',
#  '<start> passe devant',
#  '<start> vas y',
#  '<start> avance',
#  '<start> vas y',
#  '<start> poursuis',
#  '<start> passe devant',
#  '<start> vas y',
#  '<start> bien jou',
#  '<start> bon boulot',
#  '<start> beau travail',
#  '<start> attrape le',
#  '<start> attrapez le',
#  '<start> amuse toi bien',
#  '<start> amusez vous bien',
#  '<start> il essaye',
#  '<start> il est mouill',
#  '<start> aide tom',
#  '<start> aidez tom',
#  '<start> salut les mecs',
#  '<start> comme c est mignon',
#  '<start> quelle profondeur',
#  '<start> comme c est chouette',
#  '<start> comme c est gentil',
#  '<start> c est du joli',
#  '<start> comme c est agr able',
#  '<start> d p che toi',
#  '<start> grouille',
#  '<start> pressez vous',
#  '<start> fi a',
#  '<start> je m en suis bien sorti',
#  '<start> je m en suis bien sortie',
#  '<start> je l ai fait',
#  '<start> c est moi qui l ai fait',
#  '<start> j ai chou',
#  '<start> j ai oubli',
#  '<start> j ai compris',
#  '<start> j ai compris',
#  '<start> j ai capt',
#  '<start> j ai aid',
#  '<start> j ai saut',
#  '<start> j ai regard',
#  '<start> j ai r l',
#  '<start> j ai fait signe de la t te',
#  '<start> j ai ob i',
#  '<start> je t l phonai',
#  '<start> j ai t l phon',
#  '<start> je refuse',
#  '<start> je le refuse',
#  '<start> je me suis repos',
#  '<start> je me suis repos e',
#  '<start> je l ai vu',
#  '<start> je l ai vu',
#  '<start> j ai soupir',
#  '<start> je suis rest',
#  '<start> je suis rest e',
#  '<start> j ai parl',
#  '<start> je l utilise',
#  '<start> j en fais usage',
#  '<start> je m en sers',
#  '<start> je paierai',
#  '<start> je vais essayer',
#  '<start> j essaierai',
#  '<start> je suis revenu',
#  '<start> me revoil',
#  '<start> je suis chauve',
#  '<start> je suis occup',
#  '<start> je suis occup e',
#  '<start> je suis calme',
#  '<start> j ai froid',
#  '<start> je suis d tendu',
#  '<start> je suis d tendue',
#  '<start> je suis sourd',
#  '<start> je suis sourde',
#  '<start> j en ai fini',
#  '<start> je suis juste',
#  '<start> j ai la peau claire',
#  '<start> j ai le teint clair',
#  '<start> je suis rapide',
#  '<start> tout va bien',
#  '<start> je vais bien',
#  '<start> a va',
#  '<start> je suis libre',
#  '<start> je suis libre',
#  '<start> je suis disponible',
#  '<start> je suis repu',
#  '<start> je suis rassasi',
#  '<start> j en suis',
#  '<start> je suis de la partie',
#  '<start> je suis content',
#  '<start> je suis chez moi',
#  '<start> je suis en retard',
#  '<start> je suis paresseux',
#  '<start> je suis fain ant',
#  '<start> je suis paresseuse',
#  '<start> je suis fain ante',
#  '<start> je vais bien',
#  '<start> je me porte bien',
#  '<start> je suis riche',
#  '<start> je suis en s curit',
#  '<start> je suis malade',
#  '<start> j en suis certain',
#  '<start> je suis certain',
#  '<start> j en suis s r',
#  '<start> j en suis s re',
#  '<start> je suis grande',
#  '<start> je suis mince',
#  '<start> je suis ordonn',
#  '<start> je suis ordonn e',
#  '<start> je suis laid',
#  '<start> je suis laide',
#  '<start> je suis faible',
#  '<start> je vais bien',
#  '<start> je me porte bien',
#  '<start> j ai gagn',
#  '<start> je l ai emport',
#  '<start> a aide',
#  '<start> a fait mal',
#  '<start> elle marche',
#  '<start> a fonctionne',
#  '<start> c est tom',
#  '<start> c est marrant',
#  '<start> c est rigolo',
#  '<start> c est le sien',
#  '<start> c est la sienne',
#  '<start> c est nouveau',
#  '<start> c est neuf',
#  '<start> c est bizarre',
#  '<start> il est rouge',
#  '<start> c est triste',
#  '<start> d fense d entrer',
#  '<start> n entrez pas',
#  '<start> embrasse tom',
#  '<start> laisse tomber',
#  '<start> laissez tomber',
#  '<start> laissez moi',
#  '<start> laisse nous',
#  '<start> laissez nous',
#  '<start> allons y',
#  '<start> allons y',
#  '<start> attention',
#  '<start> regarde donc',
#  '<start> pouse moi',
#  '<start> pousez moi',
#  '<start> puis je partir',
#  '<start> puis je y aller',
#  '<start> puis je m y rendre',
#  '<start> sauve tom',
#  '<start> sauvez tom',
#  '<start> de quoi',
#  '<start> elle est venue',
#  '<start> elle est morte',
#  '<start> elle court',
#  '<start> assieds toi',
#  '<start> asseyez vous',
#  '<start> assieds toi',
#  '<start> assieds toi ici',
#  '<start> asseyez vous ici',
#  '<start> parle plus fort',
#  '<start> parlez plus fort',
#  '<start> l ve toi',
#  '<start> arr te tom',
#  '<start> stoppez tom',
#  '<start> go te le',
#  '<start> go te la',
#  '<start> go tez le',
#  '<start> go tez la',
#  '<start> dis le tom',
#  '<start> informez en tom',
#  '<start> g nial',
#  '<start> excellent',
#  '<start> formidable',
#  '<start> ils gagn rent',
#  '<start> elles gagn rent',
#  '<start> ils ont gagn',
#  '<start> elles ont gagn',
#  '<start> tom est venu',
#  '<start> tom est mort',
#  '<start> tom savait',
#  '<start> tom est parti',
#  '<start> tom partit',
#  '<start> tom a menti',
#  '<start> tom ment',
#  '<start> tom a perdu',
#  '<start> tom a pay',
#  '<start> trop tard',
#  '<start> faites moi confiance',
#  '<start> fais moi confiance',
#  '<start> fais un effort',
#  '<start> essaies en',
#  '<start> essayez en',
#  '<start> essaie ceci',
#  '<start> essayez ceci',
#  '<start> utilise ceci',
#  '<start> utilisez ceci',
#  '<start> emploie ceci',
#  '<start> employez ceci',
#  '<start> avertis tom',
#  '<start> pr viens tom',
#  '<start> regarde moi',
#  '<start> regardez moi',
#  '<start> regardez nous',
#  '<start> regarde nous',
#  '<start> nous sommes d accord',
#  '<start> nous irons',
#  '<start> nous allons bien',
#  '<start> pour quoi faire',
#  '<start> quoi bon',
#  '<start> qu est ce qu on s est marr s',
#  '<start> qu est ce qu on s est marr es',
#  '<start> qui est venu',
#  '<start> qui est mort',
#  '<start> qui est tomb',
#  '<start> qui d missionne',
#  '<start> qui est il',
#  '<start> cris moi',
#  '<start> crivez moi',
#  '<start> tu as perdu',
#  '<start> vous avez perdu',
#  '<start> apr s vous',
#  '<start> en joue feu',
#  '<start> suis je en retard',
#  '<start> r pondez moi',
#  '<start> assieds toi',
#  '<start> asseyez vous',
#  '<start> les oiseaux volent',
#  '<start> tes souhaits',
#  '<start> appelle la maison',
#  '<start> calmez vous',
#  '<start> calme toi',
#  '<start> pouvons nous partir',
#  '<start> pouvons nous nous en aller',
#  '<start> pouvons nous y aller',
#  '<start> attrape tom',
#  '<start> attrapez tom',
#  '<start> rattrape le',
#  '<start> calme toi',
#  '<start> reviens',
#  '<start> revenez',
#  '<start> viens ici',
#  '<start> venez l',
#  '<start> viens',
#  '<start> venez',
#  '<start> venez ici',
#  '<start> viens chez nous',
#  '<start> venez chez nous',
#  '<start> viens chez moi',
#  '<start> venez chez moi',
#  '<start> viens bient t',
#  '<start> venez bient t',
#  '<start> calmez vous',
#  '<start> ai je gagn',
#  '<start> l ai je emport',
#  '<start> est ce moi qui ai gagn',
#  '<start> faites le maintenant',
#  '<start> des chiens aboient',
#  '<start> les chiens aboient',
#  '<start> ne demande pas',
#  '<start> ne pleure pas',
#  '<start> ne meurs pas',
#  '<start> ne mourez pas',
#  '<start> ne mens pas',
#  '<start> ne courez pas',
#  '<start> ne cours pas',
#  '<start> excuse moi',
#  '<start> excusez moi',
#  '<start> pardon',
#  '<start> je vous demande pardon',
#  '<start> pla t il',
#  '<start> plait il',
#  '<start> pardon',
#  '<start> fantastique',
#  '<start> sens a',
#  '<start> sentez a',
#  '<start> touche a',
#  '<start> touchez a',
#  '<start> suis moi',
#  '<start> suis nous',
#  '<start> suivez nous',
#  '<start> oublie',
#  '<start> oublie le',
#  '<start> oubliez',
#  '<start> oubliez le',
#  '<start> laisse tomber',
#  '<start> oublie',
#  '<start> oublie le',
#  '<start> trouve un emploi',
#  '<start> trouve un boulot',
#  '<start> trouvez un emploi',
#  '<start> trouvez un boulot',
#  '<start> pr pare toi',
#  '<start> pr parez vous',
#  '<start> va le chercher',
#  '<start> allez le chercher',
#  '<start> entrez',
#  '<start> va au lit',
#  '<start> allez au lit',
#  '<start> bonne chance',
#  '<start> bonne chance',
#  '<start> attrape a',
#  '<start> attrapez a',
#  '<start> saisis toi de a',
#  '<start> saisissez vous de a',
#  '<start> attrape a',
#  '<start> attrapez a',
#  '<start> pas touche',
#  '<start> il est malade',
#  '<start> il est vieux',
#  '<start> il est dj',
#  '<start> il est bon',
#  '<start> il est paresseux',
#  '<start> il est moi',
#  '<start> il est riche',
#  '<start> il est sexy',
#  '<start> me voici',
#  '<start> voil cinq dollars',
#  '<start> halte au feu',
#  '<start> cessez le feu',
#  '<start> tiens a',
#  '<start> tenez a',
#  '<start> tenez ceci',
#  '<start> tiens ceci',
#  '<start> c est affreux',
#  '<start> comme c est bizarre',
#  '<start> comment tom va t il',
#  '<start> comment va tom',
#  '<start> j ai froid',
#  '<start> je suis bon',
#  '<start> je vais bien',
#  '<start> je suis malade',
#  '<start> je suis s r',
#  '<start> je suis certain',
#  '<start> je vous en prie',
#  '<start> je vous en conjure',
#  '<start> je vous en supplie',
#  '<start> je te prie',
#  '<start> je sais courir',
#  '<start> je sais skier',
#  '<start> j eus un mouvement de recul',
#  '<start> j ai eu un mouvement de recul',
#  '<start> je suis rentr en moi m me',
#  '<start> j ai expir',
#  '<start> j ai abandonn',
#  '<start> je donne ma langue au chat',
#  '<start> j abandonne',
#  '<start> je me suis mis avoir chaud',
#  '<start> je me suis mise avoir chaud',
#  '<start> je me suis amus',
#  '<start> je me suis amus e',
#  '<start> je me suis marr',
#  '<start> je me suis marr e',
#  '<start> je d teste a',
#  '<start> je l ai',
#  '<start> j ai frapp tom',
#  '<start> j esp re bien',
#  '<start> je me suis d p ch',
#  '<start> je me suis d p ch e',
#  '<start> j ai inspir',
#  '<start> je le savais',
#  '<start> j aime a',
#  '<start> je l ai perdu',
#  '<start> j adore a',
#  '<start> j adore a',
#  '<start> je suis s rieux',
#  '<start> je suis s rieux',
#  '<start> je dois y aller',
#  '<start> il faut que j y aille',
#  '<start> il me faut y aller',
#  '<start> il me faut partir',
#  '<start> il me faut m en aller',
#  '<start> je dois partir',
#  '<start> je dois m en aller',
#  '<start> il faut que je m en aille',
#  '<start> j en ai besoin',
#  '<start> il me le faut',
#  '<start> j ai remarqu',
#  '<start> j ai pay d avance',
#  '<start> je le promets',
#  '<start> je me suis d tendu',
#  '<start> je me suis d tendue',
#  '<start> j ai pris ma retraite',
#  '<start> j ai dit non',
#  '<start> je l ai dit',
#  '<start> je l ai vu',
#  '<start> je l ai vu',
#  '<start> je le vis',
#  '<start> j en ai vu une',
#  '<start> j en ai vu un',
#  '<start> je vous vis',
#  '<start> je te vis',
#  '<start> je t ai vue',
#  '<start> je t ai vu',
#  '<start> je vous ai vues',
#  '<start> je vous ai vus',
#  '<start> je vous ai vue',
#  '<start> je vous ai vu',
#  '<start> je vois tom',
#  '<start> j ai cri',
#  '<start> j ai tr buch',
#  '<start> j ai plan',
#  '<start> je le veux',
#  '<start> j tais nouveau',
#  '<start> j tais nouvelle',
#  '<start> j irai',
#  '<start> je me suis r veill',
#  '<start> je me suis veill',
#  '<start> je serais d accord',
#  '<start> je partirais',
#  '<start> j appellerai',
#  '<start> je cuisinerai',
#  '<start> j aiderai',
#  '<start> je vivrai',
#  '<start> j ob irai',
#  '<start> je ferai mon sac',
#  '<start> je ferai ma valise',
#  '<start> je plierai mes gaules',
#  '<start> je passerai',
#  '<start> j abandonnerai',
#  '<start> je chanterai',
#  '<start> j arr terai',
#  '<start> je nagerai',
#  '<start> je parlerai',
#  '<start> je vais parler',
#  '<start> j attendrai',
#  '<start> je marcherai',
#  '<start> je vais travailler',
#  '<start> je travaillerai',
#  '<start> je suis flic',
#  '<start> je suis un homme',
#  '<start> je suis en vie',
#  '<start> je suis vivant',
#  '<start> je suis vivante',
#  '<start> je suis seule',
#  '<start> je suis seul',
#  '<start> je suis nerv',
#  '<start> je suis en col re',
#  '<start> je suis arm',
#  '<start> je suis arm e',
#  '<start> je suis r veill',
#  '<start> je suis aveugle',
#  '<start> je suis fauch',
#  '<start> j ai d croch',
#  '<start> je suis propre',
#  '<start> je suis fou',
#  '<start> je suis folle',
#  '<start> je suis gu ri',
#  '<start> je suis gu rie',
#  '<start> j ai la t te qui tourne',
#  '<start> je suis saoul',
#  '<start> je suis so l',
#  '<start> je suis ivre',
#  '<start> je me meurs',
#  '<start> je suis en avance',
#  '<start> je suis en premier',
#  '<start> je suis difficile',
#  '<start> je suis tatillon',
#  '<start> je suis tatillonne',
#  '<start> je pars maintenant',
#  '<start> je me tire',
#  '<start> j y vais',
#  '<start> je pars',
#  '<start> je suis loyal',
#  '<start> je suis loyale',
#  '<start> je suis veinard',
#  '<start> je suis veinarde',
#  '<start> j ai du pot',
#  '<start> je suis chanceux',
#  '<start> je suis chanceuse',
#  '<start> je suis en train de mentir',
#  '<start> je suis nu',
#  '<start> je suis nue',
#  '<start> je me trouve nu',
#  '<start> je me trouve nue',
#  '<start> je suis poil',
#  '<start> je suis tranquille',
#  '<start> je suis pr te',
#  '<start> je suis pr t',
#  '<start> je suis pr t',
#  '<start> j ai raison',
#  '<start> je suis sobre',
#  '<start> excuse moi',
#  '<start> d sol',
#  '<start> excusez moi',
#  '<start> d sol',
#  '<start> je suis d sol',
#  '<start> je suis d sol e',
#  '<start> je suis coinc e',
#  '<start> je suis timide',
#  '<start> je suis fatigu',
#  '<start> je suis dur',
#  '<start> je suis dure',
#  '<start> je suis dur cuire',
#  '<start> je suis dure cuire',
#  '<start> je suis toi',
#  '<start> je suis vous',
#  '<start> j ai perdu',
#  '<start> est ce que tom va bien',
#  '<start> tom va t il bien',
#  '<start> c est grave',
#  '<start> est ce loign',
#  '<start> est ce loin',
#  '<start> est ce chaud',
#  '<start> est ce toi',
#  '<start> est ce vous',
#  '<start> est ce que c est vous',
#  '<start> a a chou',
#  '<start> il a neig',
#  '<start> a sent mauvais',
#  '<start> a pue',
#  '<start> c tait bon',
#  '<start> c tait correct',
#  '<start> c tait ok',
#  '<start> a a fonctionn',
#  '<start> a a march',
#  '<start> il est trois heures et demie',
#  '<start> il est huit heures trente',
#  '<start> il est 8 h 30',
#  '<start> c est une t l',
#  '<start> il fait froid',
#  '<start> c est froid',
#  '<start> c est sombre',
#  '<start> elle est morte',
#  '<start> c est mort',
#  '<start> il est mort',
#  '<start> c est fait',
#  '<start> c est simple',
#  '<start> c est de la nourriture',
#  '<start> c est gratuit',
#  '<start> elle est ici',
#  '<start> c est ici',
#  '<start> c est le sien',
#  '<start> c est la sienne',
#  '<start> il est tard',
#  '<start> c est perdu',
#  '<start> c est le mien',
#  '<start> c est la mienne',
#  '<start> c est moi',
#  '<start> il s agit du mien',
#  '<start> c est ouvert',
#  '<start> c est le n tre',
#  '<start> c est la n tre',
#  '<start> c est nous',
#  '<start> c est du sable',
#  '<start> il est temps',
#  '<start> c est l heure',
#  '<start> c est vrai',
#  '<start> c est du boulot',
#  '<start> restez calme',
#  '<start> garde a',
#  '<start> gardez cela',
#  '<start> garde a',
#  '<start> gardez ceci',
#  '<start> ainsi soit il',
#  '<start> laisse faire',
#  '<start> laisse moi partir',
#  '<start> laissez moi partir',
#  '<start> l che moi',
#  '<start> l chez moi',
#  '<start> laisse moi m en aller',
#  '<start> laissez moi m en aller',
#  '<start> laissez moi y aller',
#  '<start> laisse moi y aller',
#  '<start> laisse moi partir',
#  '<start> laissez moi partir',
#  '<start> laisse moi m en aller',
#  '<start> laissez moi m en aller',
#  '<start> laissez moi rentrer',
#  '<start> laissez moi entrer',
#  '<start> demandons',
#  '<start> mangeons',
#  '<start> voyons voir',
#  '<start> reste allong immobile',
#  '<start> reste allong e immobile',
#  '<start> restez allong immobile',
#  '<start> restez allong e immobile',
#  '<start> restez allong s immobiles',
#  '<start> restez allong es immobiles',
#  '<start> d tourne le regard',
#  '<start> regardez ailleurs',
#  '<start> regarde derri re toi',
#  '<start> regarde derri re',
#  '<start> regarde ici',
#  '<start> regardez ici',
#  '<start> chauffe toi',
#  '<start> chauffez vous',
#  '<start> d tends toi',
#  '<start> laisse toi aller',
#  '<start> laissez vous aller',
#  '<start> bouge de l',
#  '<start> poussez vous',
#  '<start> pousse toi',
#  '<start> joli coup',
#  '<start> pour s r',
#  '<start> mais ouais',
#  '<start> pardi',
#  '<start> bien s r',
#  '<start> pour s r',
#  '<start> je vous en prie',
#  '<start> je t en prie',
#  '<start> pardon',
#  '<start> je vous demande pardon',
#  '<start> pla t il',
#  '<start> lis ceci',
#  '<start> dis bonjour',
#  '<start> voyez ci dessus',
#  '<start> voyez ci dessous',
#  '<start> voir ci dessous',
#  '<start> capturez le',
#  '<start> attrapez le',
#  '<start> vraiment',
#  '<start> est ce s rieux',
#  '<start> s rieusement',
#  '<start> elle pleurait',
#  '<start> elle pleura',
#  '<start> elle a essay',
#  '<start> elle marche',
#  '<start> elle est chaude',
#  '<start> elle est tr s attirante',
#  '<start> signe ici',
#  '<start> signez ici',
#  '<start> signe a',
#  '<start> signez ceci',
#  '<start> ralentis',
#  '<start> ralentissez',
#  '<start> reste l cart',
#  '<start> restez l cart',
#  '<start> reste en arri re',
#  '<start> restez en arri re',
#  '<start> restez calme',
#  '<start> reste calme',
#  '<start> garde ton calme',
#  '<start> garde ton sang froid',
#  '<start> reste tranquille',
#  '<start> reste baiss',
#  '<start> restez baiss',
#  '<start> reste baiss',
#  '<start> restez baiss',
#  '<start> restez l',
#  '<start> reste ici',
#  '<start> restez ici',
#  '<start> reste mince',
#  '<start> recule',
#  '<start> reculez',
#  '<start> arr tez',
#  '<start> arr te a',
#  '<start> arr tez a',
#  '<start> arr te a',
#  '<start> arr tez les',
#  '<start> prends soin de toi',
#  '<start> soyez prudente',
#  '<start> prends soin de toi',
#  '<start> prenez soin de vous',
#  '<start> prends le mien',
#  '<start> prends la mienne',
#  '<start> prenez le mien',
#  '<start> prenez la mienne',
#  '<start> prends les miens',
#  '<start> prends les miennes',
#  '<start> prenez les miens',
#  '<start> prenez les miennes',
#  '<start> prends a',
#  '<start> prenez a',
#  '<start> merci',
#  '<start> merci',
#  '<start> il n y a pas de probl me',
#  '<start> pas de probl me',
#  '<start> ce n est pas grave',
#  '<start> a va',
#  '<start> c est a',
#  '<start> et alors',
#  '<start> ils sont tomb s',
#  '<start> elles sont tomb es',
#  '<start> ils sont partis',
#  '<start> elles sont parties',
#  '<start> ils ont menti',
#  '<start> elles ont menti',
#  '<start> ils ont perdu',
#  '<start> elles ont perdu',
#  '<start> ils nageaient',
#  '<start> elles nageaient',
#  '<start> ils nag rent',
#  '<start> elles nag rent',
#  '<start> le temps est coul',
#  '<start> tom cuisine',
#  '<start> tom pleura',
#  '<start> tom va bien',
#  '<start> tom tricote',
#  '<start> tom sait',
#  '<start> tom assure',
#  '<start> tom a parl',
#  '<start> tom a fait signe de la main',
#  '<start> tom est en train de travailler',
#  '<start> tom est gros',
#  '<start> tom est en col re',
#  '<start> tom est fou',
#  '<start> tom est triste',
#  '<start> fais confiance tom',
#  '<start> faites confiance tom',
#  '<start> essaie encore',
#  '<start> essayez de nouveau',
#  '<start> essaie de nouveau',
#  '<start> essaie le',
#  '<start> tourne gauche',
#  '<start> attends ici',
#  '<start> attends l',
#  '<start> attendez ici',
#  '<start> attendez l',
#  '<start> attention',
#  '<start> faites attention',
#  '<start> fais attention',
#  '<start> nous sommes tomb s d accord',
#  '<start> nous avons r ussi',
#  '<start> nous avons r ussi',
#  '<start> nous l avons fait',
#  '<start> nous avons oubli',
#  '<start> nous l avons vu',
#  '<start> nous l avons vue',
#  '<start> nous avons souri',
#  '<start> nous discut mes',
#  '<start> nous avons discut',
#  '<start> nous nous sommes entretenus',
#  '<start> nous nous sommes entretenues',
#  '<start> nous nous entret nmes',
#  '<start> nous attend mes',
#  '<start> nous avons attendu',
#  '<start> nous sommes all s pied',
#  '<start> nous sommes all es pied',
#  '<start> nous essayerons',
#  '<start> nous tenterons',
#  '<start> nous l emporterons',
#  '<start> nous gagnerons',
#  '<start> nous avons chaud',
#  '<start> nous sommes tristes',
#  ...]

# %%
words1=[]
for sent in corpus1:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words1.append(simple_preprocess(sent))
words1
# Out:
# [['salut'],
#  ['cours'],
#  ['courez'],
#  ['qui'],
#  ['alors'],
#  ['au', 'feu'],
#  ['aide'],
#  ['saute'],
#  ['suffit'],
#  ['stop'],
#  ['arr', 'te', 'toi'],
#  ['attends'],
#  ['attendez'],
#  ['poursuis'],
#  ['continuez'],
#  ['poursuivez'],
#  ['bonjour'],
#  ['salut'],
#  ['je', 'comprends'],
#  ['essaye'],
#  ['ai', 'gagn'],
#  ['je', 'ai', 'emport'],
#  ['ai', 'gagn'],
#  ['oh', 'non'],
#  ['attaque'],
#  ['attaquez'],
#  ['sant'],
#  ['votre', 'sant'],
#  ['merci'],
#  ['tchin', 'tchin'],
#  ['ve', 'toi'],
#  ['va', 'maintenant'],
#  ['allez', 'maintenant'],
#  ['vas', 'maintenant'],
#  ['ai', 'pig'],
#  ['compris'],
#  ['pig'],
#  ['compris'],
#  ['as', 'capt'],
#  ['monte'],
#  ['montez'],
#  ['serre', 'moi', 'dans', 'tes', 'bras'],
#  ['serrez', 'moi', 'dans', 'vos', 'bras'],
#  ['je', 'suis', 'tomb'],
#  ['je', 'suis', 'tomb'],
#  ['je', 'sais'],
#  ['je', 'suis', 'parti'],
#  ['je', 'suis', 'partie'],
#  ['ai', 'menti'],
#  ['ai', 'perdu'],
#  ['ai', 'pay'],
#  ['ai', 'ans'],
#  ['je', 'vais', 'bien'],
#  ['va'],
#  ['coutez'],
#  ['est', 'pas', 'possible'],
#  ['impossible'],
#  ['en', 'aucun', 'cas'],
#  ['sans', 'fa', 'ons'],
#  ['est', 'hors', 'de', 'question'],
#  ['il', 'en', 'est', 'pas', 'question'],
#  ['est', 'exclu'],
#  ['en', 'aucune', 'mani', 're'],
#  ['hors', 'de', 'question'],
#  ['vraiment'],
#  ['vrai'],
#  ['ah', 'bon'],
#  ['merci'],
#  ['on', 'essaye'],
#  ['nous', 'avons', 'gagn'],
#  ['nous', 'gagn', 'mes'],
#  ['nous', 'avons', 'emport'],
#  ['nous', 'emport', 'mes'],
#  ['demande', 'tom'],
#  ['fantastique'],
#  ['sois', 'calme'],
#  ['soyez', 'calme'],
#  ['soyez', 'calmes'],
#  ['sois', 'tendu'],
#  ['sois', 'juste'],
#  ['soyez', 'juste'],
#  ['soyez', 'justes'],
#  ['sois', 'quitable'],
#  ['soyez', 'quitable'],
#  ['soyez', 'quitables'],
#  ['sois', 'gentil'],
#  ['sois', 'gentil'],
#  ['sois', 'gentille'],
#  ['soyez', 'gentil'],
#  ['soyez', 'gentille'],
#  ['soyez', 'gentils'],
#  ['soyez', 'gentilles'],
#  ['gage'],
#  ['appelle', 'moi'],
#  ['appellez', 'moi'],
#  ['appelle', 'nous'],
#  ['appelez', 'nous'],
#  ['entrez'],
#  ['entre'],
#  ['entre'],
#  ['entrez'],
#  ['allez'],
#  ['allez'],
#  ['viens'],
#  ['venez'],
#  ['laisse', 'tomber'],
#  ['laissez', 'tomber'],
#  ['laisse', 'le', 'tomber'],
#  ['laissez', 'le', 'tomber'],
#  ['va', 'chercher', 'tom'],
#  ['sortez'],
#  ['sors'],
#  ['sortez'],
#  ['sors'],
#  ['casse', 'toi'],
#  ['gage'],
#  ['pars'],
#  ['va', 'te', 'faire', 'foutre'],
#  ['pars'],
#  ['gage'],
#  ['fous', 'le', 'camp'],
#  ['pars', 'ici'],
#  ['va', 'en'],
#  ['disparais'],
#  ['allez', 'vous', 'en'],
#  ['rentrez', 'la', 'maison'],
#  ['rentre', 'la', 'maison'],
#  ['rentre', 'chez', 'toi'],
#  ['rentrez', 'chez', 'vous'],
#  ['va', 'doucement'],
#  ['allez', 'doucement'],
#  ['adieu'],
#  ['la', 'revoyure'],
#  ['attends', 'un', 'peu'],
#  ['attendez', 'un', 'peu'],
#  ['tiens', 'bon'],
#  ['tenez', 'bon'],
#  ['il', 'laissa', 'tomber'],
#  ['il', 'laiss', 'tomber'],
#  ['il', 'court'],
#  ['aide', 'moi'],
#  ['aide', 'moi'],
#  ['aidez', 'moi'],
#  ['aidez', 'nous'],
#  ['aide', 'nous'],
#  ['ne', 'bouge', 'plus'],
#  ['ne', 'quittez', 'pas'],
#  ['fais', 'un', 'lin', 'tom'],
#  ['je', 'suis', 'du', 'me', 'avis'],
#  ['ai', 'pleur'],
#  ['je', 'me', 'suis', 'assoupi'],
#  ['je', 'me', 'suis', 'assoupie'],
#  ['je', 'conduis'],
#  ['je', 'fume'],
#  ['je', 'ronfle'],
#  ['je', 'pue'],
#  ['je', 'me', 'suis', 'tenu', 'debout'],
#  ['je', 'me', 'suis', 'tenue', 'debout'],
#  ['ai', 'promis'],
#  ['ai', 'jur'],
#  ['essayai'],
#  ['ai', 'essay'],
#  ['ai', 'tent'],
#  ['ai', 'fait', 'signe'],
#  ['irai'],
#  ['je', 'suis', 'tom'],
#  ['je', 'suis', 'gras'],
#  ['je', 'suis', 'gros'],
#  ['je', 'suis', 'en', 'forme'],
#  ['je', 'suis', 'touch'],
#  ['je', 'suis', 'touch'],
#  ['je', 'suis', 'malade'],
#  ['je', 'suis', 'triste'],
#  ['je', 'suis', 'timide'],
#  ['je', 'suis', 'mouill'],
#  ['je', 'suis', 'mouill'],
#  ['est', 'bibi'],
#  ['joignez', 'vous'],
#  ['joignez', 'vous', 'nous'],
#  ['garde', 'le'],
#  ['gardez', 'le'],
#  ['embrasse', 'moi'],
#  ['embrassez', 'moi'],
#  ['moi', 'aussi'],
#  ['ouvre', 'moi'],
#  ['ouvre'],
#  ['parfait'],
#  ['plus', 'tard'],
#  ['bient'],
#  ['la', 'prochaine'],
#  ['plus'],
#  ['montre', 'moi'],
#  ['montrez', 'moi'],
#  ['taisez', 'vous'],
#  ['ferme', 'la'],
#  ['tais', 'toi'],
#  ['ferme', 'la'],
#  ['la', 'ferme'],
#  ['pas', 'grave'],
#  ['plus', 'tard'],
#  ['prends', 'le'],
#  ['prenez', 'le'],
#  ['prends', 'le'],
#  ['prenez', 'le'],
#  ['dis', 'moi'],
#  ['dites', 'moi'],
#  ['tom', 'gagn'],
#  ['veille', 'toi'],
#  ['veille', 'toi'],
#  ['veillez', 'vous'],
#  ['veille', 'toi'],
#  ['veillez', 'vous'],
#  ['lave', 'toi'],
#  ['lavez', 'vous'],
#  ['nous', 'savons'],
#  ['nous', 'perd', 'mes'],
#  ['nous', 'avons', 'perdu'],
#  ['nous', 'mes', 'battus'],
#  ['nous', 'mes', 'battues'],
#  ['nous', 'mes', 'faits'],
#  ['nous', 'mes', 'faites'],
#  ['nous', 'avons', 'faits'],
#  ['nous', 'avons', 'faites'],
#  ['nous', 'avons', 'battus'],
#  ['nous', 'avons', 'battues'],
#  ['bienvenue'],
#  ['qui', 'gagn'],
#  ['qui', 'emport'],
#  ['tu', 'cours'],
#  ['suis', 'je', 'gros'],
#  ['suis', 'je', 'grosse'],
#  ['demande', 'leur'],
#  ['demandez', 'leur'],
#  ['recule'],
#  ['reculez'],
#  ['recule'],
#  ['reculez'],
#  ['retire', 'toi'],
#  ['retirez', 'vous'],
#  ['sois', 'un', 'homme'],
#  ['soyez', 'un', 'homme'],
#  ['sois', 'calme'],
#  ['soyez', 'calme'],
#  ['soyez', 'calmes'],
#  ['aucune', 'id'],
#  ['en', 'sais', 'foutre', 'rien'],
#  ['appelle', 'tom'],
#  ['appelez', 'tom'],
#  ['courage'],
#  ['tends', 'toi'],
#  ['menottez', 'le'],
#  ['avance'],
#  ['avancez'],
#  ['continue', 'rouler'],
#  ['continuez', 'rouler'],
#  ['trouve', 'tom'],
#  ['trouvez', 'tom'],
#  ['parez', 'ceci'],
#  ['pare'],
#  ['che', 'toi'],
#  ['descends'],
#  ['descendez'],
#  ['che', 'toi'],
#  ['chez', 'vous'],
#  ['va', 'voir', 'ailleurs', 'si', 'suis'],
#  ['gage'],
#  ['va', 'au', 'diable'],
#  ['sois', 'aliste'],
#  ['passe', 'devant'],
#  ['vas'],
#  ['avance'],
#  ['vas'],
#  ['poursuis'],
#  ['passe', 'devant'],
#  ['vas'],
#  ['bien', 'jou'],
#  ['bon', 'boulot'],
#  ['beau', 'travail'],
#  ['attrape', 'le'],
#  ['attrapez', 'le'],
#  ['amuse', 'toi', 'bien'],
#  ['amusez', 'vous', 'bien'],
#  ['il', 'essaye'],
#  ['il', 'est', 'mouill'],
#  ['aide', 'tom'],
#  ['aidez', 'tom'],
#  ['salut', 'les', 'mecs'],
#  ['comme', 'est', 'mignon'],
#  ['quelle', 'profondeur'],
#  ['comme', 'est', 'chouette'],
#  ['comme', 'est', 'gentil'],
#  ['est', 'du', 'joli'],
#  ['comme', 'est', 'agr', 'able'],
#  ['che', 'toi'],
#  ['grouille'],
#  ['pressez', 'vous'],
#  ['fi'],
#  ['je', 'en', 'suis', 'bien', 'sorti'],
#  ['je', 'en', 'suis', 'bien', 'sortie'],
#  ['je', 'ai', 'fait'],
#  ['est', 'moi', 'qui', 'ai', 'fait'],
#  ['ai', 'chou'],
#  ['ai', 'oubli'],
#  ['ai', 'compris'],
#  ['ai', 'compris'],
#  ['ai', 'capt'],
#  ['ai', 'aid'],
#  ['ai', 'saut'],
#  ['ai', 'regard'],
#  ['ai'],
#  ['ai', 'fait', 'signe', 'de', 'la', 'te'],
#  ['ai', 'ob'],
#  ['je', 'phonai'],
#  ['ai', 'phon'],
#  ['je', 'refuse'],
#  ['je', 'le', 'refuse'],
#  ['je', 'me', 'suis', 'repos'],
#  ['je', 'me', 'suis', 'repos'],
#  ['je', 'ai', 'vu'],
#  ['je', 'ai', 'vu'],
#  ['ai', 'soupir'],
#  ['je', 'suis', 'rest'],
#  ['je', 'suis', 'rest'],
#  ['ai', 'parl'],
#  ['je', 'utilise'],
#  ['en', 'fais', 'usage'],
#  ['je', 'en', 'sers'],
#  ['je', 'paierai'],
#  ['je', 'vais', 'essayer'],
#  ['essaierai'],
#  ['je', 'suis', 'revenu'],
#  ['me', 'revoil'],
#  ['je', 'suis', 'chauve'],
#  ['je', 'suis', 'occup'],
#  ['je', 'suis', 'occup'],
#  ['je', 'suis', 'calme'],
#  ['ai', 'froid'],
#  ['je', 'suis', 'tendu'],
#  ['je', 'suis', 'tendue'],
#  ['je', 'suis', 'sourd'],
#  ['je', 'suis', 'sourde'],
#  ['en', 'ai', 'fini'],
#  ['je', 'suis', 'juste'],
#  ['ai', 'la', 'peau', 'claire'],
#  ['ai', 'le', 'teint', 'clair'],
#  ['je', 'suis', 'rapide'],
#  ['tout', 'va', 'bien'],
#  ['je', 'vais', 'bien'],
#  ['va'],
#  ['je', 'suis', 'libre'],
#  ['je', 'suis', 'libre'],
#  ['je', 'suis', 'disponible'],
#  ['je', 'suis', 'repu'],
#  ['je', 'suis', 'rassasi'],
#  ['en', 'suis'],
#  ['je', 'suis', 'de', 'la', 'partie'],
#  ['je', 'suis', 'content'],
#  ['je', 'suis', 'chez', 'moi'],
#  ['je', 'suis', 'en', 'retard'],
#  ['je', 'suis', 'paresseux'],
#  ['je', 'suis', 'fain', 'ant'],
#  ['je', 'suis', 'paresseuse'],
#  ['je', 'suis', 'fain', 'ante'],
#  ['je', 'vais', 'bien'],
#  ['je', 'me', 'porte', 'bien'],
#  ['je', 'suis', 'riche'],
#  ['je', 'suis', 'en', 'curit'],
#  ['je', 'suis', 'malade'],
#  ['en', 'suis', 'certain'],
#  ['je', 'suis', 'certain'],
#  ['en', 'suis'],
#  ['en', 'suis', 're'],
#  ['je', 'suis', 'grande'],
#  ['je', 'suis', 'mince'],
#  ['je', 'suis', 'ordonn'],
#  ['je', 'suis', 'ordonn'],
#  ['je', 'suis', 'laid'],
#  ['je', 'suis', 'laide'],
#  ['je', 'suis', 'faible'],
#  ['je', 'vais', 'bien'],
#  ['je', 'me', 'porte', 'bien'],
#  ['ai', 'gagn'],
#  ['je', 'ai', 'emport'],
#  ['aide'],
#  ['fait', 'mal'],
#  ['elle', 'marche'],
#  ['fonctionne'],
#  ['est', 'tom'],
#  ['est', 'marrant'],
#  ['est', 'rigolo'],
#  ['est', 'le', 'sien'],
#  ['est', 'la', 'sienne'],
#  ['est', 'nouveau'],
#  ['est', 'neuf'],
#  ['est', 'bizarre'],
#  ['il', 'est', 'rouge'],
#  ['est', 'triste'],
#  ['fense', 'entrer'],
#  ['entrez', 'pas'],
#  ['embrasse', 'tom'],
#  ['laisse', 'tomber'],
#  ['laissez', 'tomber'],
#  ['laissez', 'moi'],
#  ['laisse', 'nous'],
#  ['laissez', 'nous'],
#  ['allons'],
#  ['allons'],
#  ['attention'],
#  ['regarde', 'donc'],
#  ['pouse', 'moi'],
#  ['pousez', 'moi'],
#  ['puis', 'je', 'partir'],
#  ['puis', 'je', 'aller'],
#  ['puis', 'je', 'rendre'],
#  ['sauve', 'tom'],
#  ['sauvez', 'tom'],
#  ['de', 'quoi'],
#  ['elle', 'est', 'venue'],
#  ['elle', 'est', 'morte'],
#  ['elle', 'court'],
#  ['assieds', 'toi'],
#  ['asseyez', 'vous'],
#  ['assieds', 'toi'],
#  ['assieds', 'toi', 'ici'],
#  ['asseyez', 'vous', 'ici'],
#  ['parle', 'plus', 'fort'],
#  ['parlez', 'plus', 'fort'],
#  ['ve', 'toi'],
#  ['arr', 'te', 'tom'],
#  ['stoppez', 'tom'],
#  ['go', 'te', 'le'],
#  ['go', 'te', 'la'],
#  ['go', 'tez', 'le'],
#  ['go', 'tez', 'la'],
#  ['dis', 'le', 'tom'],
#  ['informez', 'en', 'tom'],
#  ['nial'],
#  ['excellent'],
#  ['formidable'],
#  ['ils', 'gagn', 'rent'],
#  ['elles', 'gagn', 'rent'],
#  ['ils', 'ont', 'gagn'],
#  ['elles', 'ont', 'gagn'],
#  ['tom', 'est', 'venu'],
#  ['tom', 'est', 'mort'],
#  ['tom', 'savait'],
#  ['tom', 'est', 'parti'],
#  ['tom', 'partit'],
#  ['tom', 'menti'],
#  ['tom', 'ment'],
#  ['tom', 'perdu'],
#  ['tom', 'pay'],
#  ['trop', 'tard'],
#  ['faites', 'moi', 'confiance'],
#  ['fais', 'moi', 'confiance'],
#  ['fais', 'un', 'effort'],
#  ['essaies', 'en'],
#  ['essayez', 'en'],
#  ['essaie', 'ceci'],
#  ['essayez', 'ceci'],
#  ['utilise', 'ceci'],
#  ['utilisez', 'ceci'],
#  ['emploie', 'ceci'],
#  ['employez', 'ceci'],
#  ['avertis', 'tom'],
#  ['pr', 'viens', 'tom'],
#  ['regarde', 'moi'],
#  ['regardez', 'moi'],
#  ['regardez', 'nous'],
#  ['regarde', 'nous'],
#  ['nous', 'sommes', 'accord'],
#  ['nous', 'irons'],
#  ['nous', 'allons', 'bien'],
#  ['pour', 'quoi', 'faire'],
#  ['quoi', 'bon'],
#  ['qu', 'est', 'ce', 'qu', 'on', 'est', 'marr'],
#  ['qu', 'est', 'ce', 'qu', 'on', 'est', 'marr', 'es'],
#  ['qui', 'est', 'venu'],
#  ['qui', 'est', 'mort'],
#  ['qui', 'est', 'tomb'],
#  ['qui', 'missionne'],
#  ['qui', 'est', 'il'],
#  ['cris', 'moi'],
#  ['crivez', 'moi'],
#  ['tu', 'as', 'perdu'],
#  ['vous', 'avez', 'perdu'],
#  ['apr', 'vous'],
#  ['en', 'joue', 'feu'],
#  ['suis', 'je', 'en', 'retard'],
#  ['pondez', 'moi'],
#  ['assieds', 'toi'],
#  ['asseyez', 'vous'],
#  ['les', 'oiseaux', 'volent'],
#  ['tes', 'souhaits'],
#  ['appelle', 'la', 'maison'],
#  ['calmez', 'vous'],
#  ['calme', 'toi'],
#  ['pouvons', 'nous', 'partir'],
#  ['pouvons', 'nous', 'nous', 'en', 'aller'],
#  ['pouvons', 'nous', 'aller'],
#  ['attrape', 'tom'],
#  ['attrapez', 'tom'],
#  ['rattrape', 'le'],
#  ['calme', 'toi'],
#  ['reviens'],
#  ['revenez'],
#  ['viens', 'ici'],
#  ['venez'],
#  ['viens'],
#  ['venez'],
#  ['venez', 'ici'],
#  ['viens', 'chez', 'nous'],
#  ['venez', 'chez', 'nous'],
#  ['viens', 'chez', 'moi'],
#  ['venez', 'chez', 'moi'],
#  ['viens', 'bient'],
#  ['venez', 'bient'],
#  ['calmez', 'vous'],
#  ['ai', 'je', 'gagn'],
#  ['ai', 'je', 'emport'],
#  ['est', 'ce', 'moi', 'qui', 'ai', 'gagn'],
#  ['faites', 'le', 'maintenant'],
#  ['des', 'chiens', 'aboient'],
#  ['les', 'chiens', 'aboient'],
#  ['ne', 'demande', 'pas'],
#  ['ne', 'pleure', 'pas'],
#  ['ne', 'meurs', 'pas'],
#  ['ne', 'mourez', 'pas'],
#  ['ne', 'mens', 'pas'],
#  ['ne', 'courez', 'pas'],
#  ['ne', 'cours', 'pas'],
#  ['excuse', 'moi'],
#  ['excusez', 'moi'],
#  ['pardon'],
#  ['je', 'vous', 'demande', 'pardon'],
#  ['pla', 'il'],
#  ['plait', 'il'],
#  ['pardon'],
#  ['fantastique'],
#  ['sens'],
#  ['sentez'],
#  ['touche'],
#  ['touchez'],
#  ['suis', 'moi'],
#  ['suis', 'nous'],
#  ['suivez', 'nous'],
#  ['oublie'],
#  ['oublie', 'le'],
#  ['oubliez'],
#  ['oubliez', 'le'],
#  ['laisse', 'tomber'],
#  ['oublie'],
#  ['oublie', 'le'],
#  ['trouve', 'un', 'emploi'],
#  ['trouve', 'un', 'boulot'],
#  ['trouvez', 'un', 'emploi'],
#  ['trouvez', 'un', 'boulot'],
#  ['pr', 'pare', 'toi'],
#  ['pr', 'parez', 'vous'],
#  ['va', 'le', 'chercher'],
#  ['allez', 'le', 'chercher'],
#  ['entrez'],
#  ['va', 'au', 'lit'],
#  ['allez', 'au', 'lit'],
#  ['bonne', 'chance'],
#  ['bonne', 'chance'],
#  ['attrape'],
#  ['attrapez'],
#  ['saisis', 'toi', 'de'],
#  ['saisissez', 'vous', 'de'],
#  ['attrape'],
#  ['attrapez'],
#  ['pas', 'touche'],
#  ['il', 'est', 'malade'],
#  ['il', 'est', 'vieux'],
#  ['il', 'est', 'dj'],
#  ['il', 'est', 'bon'],
#  ['il', 'est', 'paresseux'],
#  ['il', 'est', 'moi'],
#  ['il', 'est', 'riche'],
#  ['il', 'est', 'sexy'],
#  ['me', 'voici'],
#  ['voil', 'cinq', 'dollars'],
#  ['halte', 'au', 'feu'],
#  ['cessez', 'le', 'feu'],
#  ['tiens'],
#  ['tenez'],
#  ['tenez', 'ceci'],
#  ['tiens', 'ceci'],
#  ['est', 'affreux'],
#  ['comme', 'est', 'bizarre'],
#  ['comment', 'tom', 'va', 'il'],
#  ['comment', 'va', 'tom'],
#  ['ai', 'froid'],
#  ['je', 'suis', 'bon'],
#  ['je', 'vais', 'bien'],
#  ['je', 'suis', 'malade'],
#  ['je', 'suis'],
#  ['je', 'suis', 'certain'],
#  ['je', 'vous', 'en', 'prie'],
#  ['je', 'vous', 'en', 'conjure'],
#  ['je', 'vous', 'en', 'supplie'],
#  ['je', 'te', 'prie'],
#  ['je', 'sais', 'courir'],
#  ['je', 'sais', 'skier'],
#  ['eus', 'un', 'mouvement', 'de', 'recul'],
#  ['ai', 'eu', 'un', 'mouvement', 'de', 'recul'],
#  ['je', 'suis', 'rentr', 'en', 'moi', 'me'],
#  ['ai', 'expir'],
#  ['ai', 'abandonn'],
#  ['je', 'donne', 'ma', 'langue', 'au', 'chat'],
#  ['abandonne'],
#  ['je', 'me', 'suis', 'mis', 'avoir', 'chaud'],
#  ['je', 'me', 'suis', 'mise', 'avoir', 'chaud'],
#  ['je', 'me', 'suis', 'amus'],
#  ['je', 'me', 'suis', 'amus'],
#  ['je', 'me', 'suis', 'marr'],
#  ['je', 'me', 'suis', 'marr'],
#  ['je', 'teste'],
#  ['je', 'ai'],
#  ['ai', 'frapp', 'tom'],
#  ['esp', 're', 'bien'],
#  ['je', 'me', 'suis', 'ch'],
#  ['je', 'me', 'suis', 'ch'],
#  ['ai', 'inspir'],
#  ['je', 'le', 'savais'],
#  ['aime'],
#  ['je', 'ai', 'perdu'],
#  ['adore'],
#  ['adore'],
#  ['je', 'suis', 'rieux'],
#  ['je', 'suis', 'rieux'],
#  ['je', 'dois', 'aller'],
#  ['il', 'faut', 'que', 'aille'],
#  ['il', 'me', 'faut', 'aller'],
#  ['il', 'me', 'faut', 'partir'],
#  ['il', 'me', 'faut', 'en', 'aller'],
#  ['je', 'dois', 'partir'],
#  ['je', 'dois', 'en', 'aller'],
#  ['il', 'faut', 'que', 'je', 'en', 'aille'],
#  ['en', 'ai', 'besoin'],
#  ['il', 'me', 'le', 'faut'],
#  ['ai', 'remarqu'],
#  ['ai', 'pay', 'avance'],
#  ['je', 'le', 'promets'],
#  ['je', 'me', 'suis', 'tendu'],
#  ['je', 'me', 'suis', 'tendue'],
#  ['ai', 'pris', 'ma', 'retraite'],
#  ['ai', 'dit', 'non'],
#  ['je', 'ai', 'dit'],
#  ['je', 'ai', 'vu'],
#  ['je', 'ai', 'vu'],
#  ['je', 'le', 'vis'],
#  ['en', 'ai', 'vu', 'une'],
#  ['en', 'ai', 'vu', 'un'],
#  ['je', 'vous', 'vis'],
#  ['je', 'te', 'vis'],
#  ['je', 'ai', 'vue'],
#  ['je', 'ai', 'vu'],
#  ['je', 'vous', 'ai', 'vues'],
#  ['je', 'vous', 'ai', 'vus'],
#  ['je', 'vous', 'ai', 'vue'],
#  ['je', 'vous', 'ai', 'vu'],
#  ['je', 'vois', 'tom'],
#  ['ai', 'cri'],
#  ['ai', 'tr', 'buch'],
#  ['ai', 'plan'],
#  ['je', 'le', 'veux'],
#  ['tais', 'nouveau'],
#  ['tais', 'nouvelle'],
#  ['irai'],
#  ['je', 'me', 'suis', 'veill'],
#  ['je', 'me', 'suis', 'veill'],
#  ['je', 'serais', 'accord'],
#  ['je', 'partirais'],
#  ['appellerai'],
#  ['je', 'cuisinerai'],
#  ['aiderai'],
#  ['je', 'vivrai'],
#  ['ob', 'irai'],
#  ['je', 'ferai', 'mon', 'sac'],
#  ['je', 'ferai', 'ma', 'valise'],
#  ['je', 'plierai', 'mes', 'gaules'],
#  ['je', 'passerai'],
#  ['abandonnerai'],
#  ['je', 'chanterai'],
#  ['arr', 'terai'],
#  ['je', 'nagerai'],
#  ['je', 'parlerai'],
#  ['je', 'vais', 'parler'],
#  ['attendrai'],
#  ['je', 'marcherai'],
#  ['je', 'vais', 'travailler'],
#  ['je', 'travaillerai'],
#  ['je', 'suis', 'flic'],
#  ['je', 'suis', 'un', 'homme'],
#  ['je', 'suis', 'en', 'vie'],
#  ['je', 'suis', 'vivant'],
#  ['je', 'suis', 'vivante'],
#  ['je', 'suis', 'seule'],
#  ['je', 'suis', 'seul'],
#  ['je', 'suis', 'nerv'],
#  ['je', 'suis', 'en', 'col', 're'],
#  ['je', 'suis', 'arm'],
#  ['je', 'suis', 'arm'],
#  ['je', 'suis', 'veill'],
#  ['je', 'suis', 'aveugle'],
#  ['je', 'suis', 'fauch'],
#  ['ai', 'croch'],
#  ['je', 'suis', 'propre'],
#  ['je', 'suis', 'fou'],
#  ['je', 'suis', 'folle'],
#  ['je', 'suis', 'gu', 'ri'],
#  ['je', 'suis', 'gu', 'rie'],
#  ['ai', 'la', 'te', 'qui', 'tourne'],
#  ['je', 'suis', 'saoul'],
#  ['je', 'suis', 'so'],
#  ['je', 'suis', 'ivre'],
#  ['je', 'me', 'meurs'],
#  ['je', 'suis', 'en', 'avance'],
#  ['je', 'suis', 'en', 'premier'],
#  ['je', 'suis', 'difficile'],
#  ['je', 'suis', 'tatillon'],
#  ['je', 'suis', 'tatillonne'],
#  ['je', 'pars', 'maintenant'],
#  ['je', 'me', 'tire'],
#  ['vais'],
#  ['je', 'pars'],
#  ['je', 'suis', 'loyal'],
#  ['je', 'suis', 'loyale'],
#  ['je', 'suis', 'veinard'],
#  ['je', 'suis', 'veinarde'],
#  ['ai', 'du', 'pot'],
#  ['je', 'suis', 'chanceux'],
#  ['je', 'suis', 'chanceuse'],
#  ['je', 'suis', 'en', 'train', 'de', 'mentir'],
#  ['je', 'suis', 'nu'],
#  ['je', 'suis', 'nue'],
#  ['je', 'me', 'trouve', 'nu'],
#  ['je', 'me', 'trouve', 'nue'],
#  ['je', 'suis', 'poil'],
#  ['je', 'suis', 'tranquille'],
#  ['je', 'suis', 'pr', 'te'],
#  ['je', 'suis', 'pr'],
#  ['je', 'suis', 'pr'],
#  ['ai', 'raison'],
#  ['je', 'suis', 'sobre'],
#  ['excuse', 'moi'],
#  ['sol'],
#  ['excusez', 'moi'],
#  ['sol'],
#  ['je', 'suis', 'sol'],
#  ['je', 'suis', 'sol'],
#  ['je', 'suis', 'coinc'],
#  ['je', 'suis', 'timide'],
#  ['je', 'suis', 'fatigu'],
#  ['je', 'suis', 'dur'],
#  ['je', 'suis', 'dure'],
#  ['je', 'suis', 'dur', 'cuire'],
#  ['je', 'suis', 'dure', 'cuire'],
#  ['je', 'suis', 'toi'],
#  ['je', 'suis', 'vous'],
#  ['ai', 'perdu'],
#  ['est', 'ce', 'que', 'tom', 'va', 'bien'],
#  ['tom', 'va', 'il', 'bien'],
#  ['est', 'grave'],
#  ['est', 'ce', 'loign'],
#  ['est', 'ce', 'loin'],
#  ['est', 'ce', 'chaud'],
#  ['est', 'ce', 'toi'],
#  ['est', 'ce', 'vous'],
#  ['est', 'ce', 'que', 'est', 'vous'],
#  ['chou'],
#  ['il', 'neig'],
#  ['sent', 'mauvais'],
#  ['pue'],
#  ['tait', 'bon'],
#  ['tait', 'correct'],
#  ['tait', 'ok'],
#  ['fonctionn'],
#  ['march'],
#  ['il', 'est', 'trois', 'heures', 'et', 'demie'],
#  ['il', 'est', 'huit', 'heures', 'trente'],
#  ['il', 'est'],
#  ['est', 'une'],
#  ['il', 'fait', 'froid'],
#  ['est', 'froid'],
#  ['est', 'sombre'],
#  ['elle', 'est', 'morte'],
#  ['est', 'mort'],
#  ['il', 'est', 'mort'],
#  ['est', 'fait'],
#  ['est', 'simple'],
#  ['est', 'de', 'la', 'nourriture'],
#  ['est', 'gratuit'],
#  ['elle', 'est', 'ici'],
#  ['est', 'ici'],
#  ['est', 'le', 'sien'],
#  ['est', 'la', 'sienne'],
#  ['il', 'est', 'tard'],
#  ['est', 'perdu'],
#  ['est', 'le', 'mien'],
#  ['est', 'la', 'mienne'],
#  ['est', 'moi'],
#  ['il', 'agit', 'du', 'mien'],
#  ['est', 'ouvert'],
#  ['est', 'le', 'tre'],
#  ['est', 'la', 'tre'],
#  ['est', 'nous'],
#  ['est', 'du', 'sable'],
#  ['il', 'est', 'temps'],
#  ['est', 'heure'],
#  ['est', 'vrai'],
#  ['est', 'du', 'boulot'],
#  ['restez', 'calme'],
#  ['garde'],
#  ['gardez', 'cela'],
#  ['garde'],
#  ['gardez', 'ceci'],
#  ['ainsi', 'soit', 'il'],
#  ['laisse', 'faire'],
#  ['laisse', 'moi', 'partir'],
#  ['laissez', 'moi', 'partir'],
#  ['che', 'moi'],
#  ['chez', 'moi'],
#  ['laisse', 'moi', 'en', 'aller'],
#  ['laissez', 'moi', 'en', 'aller'],
#  ['laissez', 'moi', 'aller'],
#  ['laisse', 'moi', 'aller'],
#  ['laisse', 'moi', 'partir'],
#  ['laissez', 'moi', 'partir'],
#  ['laisse', 'moi', 'en', 'aller'],
#  ['laissez', 'moi', 'en', 'aller'],
#  ['laissez', 'moi', 'rentrer'],
#  ['laissez', 'moi', 'entrer'],
#  ['demandons'],
#  ['mangeons'],
#  ['voyons', 'voir'],
#  ['reste', 'allong', 'immobile'],
#  ['reste', 'allong', 'immobile'],
#  ['restez', 'allong', 'immobile'],
#  ['restez', 'allong', 'immobile'],
#  ['restez', 'allong', 'immobiles'],
#  ['restez', 'allong', 'es', 'immobiles'],
#  ['tourne', 'le', 'regard'],
#  ['regardez', 'ailleurs'],
#  ['regarde', 'derri', 're', 'toi'],
#  ['regarde', 'derri', 're'],
#  ['regarde', 'ici'],
#  ['regardez', 'ici'],
#  ['chauffe', 'toi'],
#  ['chauffez', 'vous'],
#  ['tends', 'toi'],
#  ['laisse', 'toi', 'aller'],
#  ['laissez', 'vous', 'aller'],
#  ['bouge', 'de'],
#  ['poussez', 'vous'],
#  ['pousse', 'toi'],
#  ['joli', 'coup'],
#  ['pour'],
#  ['mais', 'ouais'],
#  ['pardi'],
#  ['bien'],
#  ['pour'],
#  ['je', 'vous', 'en', 'prie'],
#  ['je', 'en', 'prie'],
#  ['pardon'],
#  ['je', 'vous', 'demande', 'pardon'],
#  ['pla', 'il'],
#  ['lis', 'ceci'],
#  ['dis', 'bonjour'],
#  ['voyez', 'ci', 'dessus'],
#  ['voyez', 'ci', 'dessous'],
#  ['voir', 'ci', 'dessous'],
#  ['capturez', 'le'],
#  ['attrapez', 'le'],
#  ['vraiment'],
#  ['est', 'ce', 'rieux'],
#  ['rieusement'],
#  ['elle', 'pleurait'],
#  ['elle', 'pleura'],
#  ['elle', 'essay'],
#  ['elle', 'marche'],
#  ['elle', 'est', 'chaude'],
#  ['elle', 'est', 'tr', 'attirante'],
#  ['signe', 'ici'],
#  ['signez', 'ici'],
#  ['signe'],
#  ['signez', 'ceci'],
#  ['ralentis'],
#  ['ralentissez'],
#  ['reste', 'cart'],
#  ['restez', 'cart'],
#  ['reste', 'en', 'arri', 're'],
#  ['restez', 'en', 'arri', 're'],
#  ['restez', 'calme'],
#  ['reste', 'calme'],
#  ['garde', 'ton', 'calme'],
#  ['garde', 'ton', 'sang', 'froid'],
#  ['reste', 'tranquille'],
#  ['reste', 'baiss'],
#  ['restez', 'baiss'],
#  ['reste', 'baiss'],
#  ['restez', 'baiss'],
#  ['restez'],
#  ['reste', 'ici'],
#  ['restez', 'ici'],
#  ['reste', 'mince'],
#  ['recule'],
#  ['reculez'],
#  ['arr', 'tez'],
#  ['arr', 'te'],
#  ['arr', 'tez'],
#  ['arr', 'te'],
#  ['arr', 'tez', 'les'],
#  ['prends', 'soin', 'de', 'toi'],
#  ['soyez', 'prudente'],
#  ['prends', 'soin', 'de', 'toi'],
#  ['prenez', 'soin', 'de', 'vous'],
#  ['prends', 'le', 'mien'],
#  ['prends', 'la', 'mienne'],
#  ['prenez', 'le', 'mien'],
#  ['prenez', 'la', 'mienne'],
#  ['prends', 'les', 'miens'],
#  ['prends', 'les', 'miennes'],
#  ['prenez', 'les', 'miens'],
#  ['prenez', 'les', 'miennes'],
#  ['prends'],
#  ['prenez'],
#  ['merci'],
#  ['merci'],
#  ['il', 'pas', 'de', 'probl', 'me'],
#  ['pas', 'de', 'probl', 'me'],
#  ['ce', 'est', 'pas', 'grave'],
#  ['va'],
#  ['est'],
#  ['et', 'alors'],
#  ['ils', 'sont', 'tomb'],
#  ['elles', 'sont', 'tomb', 'es'],
#  ['ils', 'sont', 'partis'],
#  ['elles', 'sont', 'parties'],
#  ['ils', 'ont', 'menti'],
#  ['elles', 'ont', 'menti'],
#  ['ils', 'ont', 'perdu'],
#  ['elles', 'ont', 'perdu'],
#  ['ils', 'nageaient'],
#  ['elles', 'nageaient'],
#  ['ils', 'nag', 'rent'],
#  ['elles', 'nag', 'rent'],
#  ['le', 'temps', 'est', 'coul'],
#  ['tom', 'cuisine'],
#  ['tom', 'pleura'],
#  ['tom', 'va', 'bien'],
#  ['tom', 'tricote'],
#  ['tom', 'sait'],
#  ['tom', 'assure'],
#  ['tom', 'parl'],
#  ['tom', 'fait', 'signe', 'de', 'la', 'main'],
#  ['tom', 'est', 'en', 'train', 'de', 'travailler'],
#  ['tom', 'est', 'gros'],
#  ['tom', 'est', 'en', 'col', 're'],
#  ['tom', 'est', 'fou'],
#  ['tom', 'est', 'triste'],
#  ['fais', 'confiance', 'tom'],
#  ['faites', 'confiance', 'tom'],
#  ['essaie', 'encore'],
#  ['essayez', 'de', 'nouveau'],
#  ['essaie', 'de', 'nouveau'],
#  ['essaie', 'le'],
#  ['tourne', 'gauche'],
#  ['attends', 'ici'],
#  ['attends'],
#  ['attendez', 'ici'],
#  ['attendez'],
#  ['attention'],
#  ['faites', 'attention'],
#  ['fais', 'attention'],
#  ['nous', 'sommes', 'tomb', 'accord'],
#  ['nous', 'avons', 'ussi'],
#  ['nous', 'avons', 'ussi'],
#  ['nous', 'avons', 'fait'],
#  ['nous', 'avons', 'oubli'],
#  ['nous', 'avons', 'vu'],
#  ['nous', 'avons', 'vue'],
#  ['nous', 'avons', 'souri'],
#  ['nous', 'discut', 'mes'],
#  ['nous', 'avons', 'discut'],
#  ['nous', 'nous', 'sommes', 'entretenus'],
#  ['nous', 'nous', 'sommes', 'entretenues'],
#  ['nous', 'nous', 'entret', 'nmes'],
#  ['nous', 'attend', 'mes'],
#  ['nous', 'avons', 'attendu'],
#  ['nous', 'sommes', 'all', 'pied'],
#  ['nous', 'sommes', 'all', 'es', 'pied'],
#  ['nous', 'essayerons'],
#  ['nous', 'tenterons'],
#  ['nous', 'emporterons'],
#  ['nous', 'gagnerons'],
#  ['nous', 'avons', 'chaud'],
#  ['nous', 'sommes', 'tristes'],
#  ...]

# %%
max_len_output = max(len(sentence) for sentence in words1)
longest_sentence = max(words1, key=len)

print("Sentence with max words:", longest_sentence)
max_len_output= max_len_output+1            # As there will be <start> and <end>
print("Max number of words:", max_len_output)
# Out:
# Sentence with max words: ['ce', 'est', 'pas', 'moi', 'qu', 'il', 'faut', 'le', 'demander']
# Max number of words: 10

# %% [markdown]
# ### Get unique words

# %%
all_words1 = [word for sentence in words1 for word in sentence]

unique_words_output = set(all_words1)

# Count them
print("Number of unique words:", len(unique_words_output))
print("Unique words:", unique_words_output)
# Out:
# Number of unique words: 2203
# Unique words: {'tends', 'dessous', 'trompe', 'mal', 'trouvez', 'confectionn', 'endormie', 'taudis', 'bi', 'heurt', 'vot', 'faveur', 'aide', 'signe', 'mani', 'sol', 'date', 'ravi', 'interrogez', 'mentes', 'ralentissez', 'lave', 'faim', 'mort', 'profondeur', 'cachons', 'brave', 'protest', 'daube', 'nuageux', 'rebondissons', 'donner', 'soupir', 'contrefa', 'tripes', 'esseul', 'coinc', 'facile', 'rencontr', 'vite', 'pauvre', 'assoupi', 'regard', 'faible', 'verai', 'verre', 'entrez', 'amusez', 'sus', 'vint', 'cultiv', 'vomi', 'plait', 'vos', 'biais', 'ch', 'demi', 'passe', 'assure', 'ts', 'vient', 'chauffer', 'devez', 'livres', 'cass', 'connais', 'les', 'premi', 'route', 'rapide', 'rire', 'rel', 'manger', 'attrist', 'ritable', 'perdons', 'sain', 'sent', 'arnaque', 'fout', 'calcul', 'ador', 'jubilez', 'partit', 'calmez', 'bras', 'conna', 'excusez', 'range', 'partis', 'dire', 'interrompre', 'ci', 'ai', 'pensionn', 'suivez', 'pare', 'doute', 'remont', 'tourne', 'coll', 'ra', 'injuste', 'intelligentes', 'vanoui', 'rieux', 'prom', 'parvenir', 'pourrions', 'choc', 'na', 'sortirai', 'arriver', 'sympas', 'liste', 'suffit', 'vers', 'touch', 'navire', 'paie', 'prise', 'fini', 'entrer', 'avise', 'donna', 'effarant', 'diable', 'chantent', 'lasses', 'vieille', 'grand', 'imp', 'gaffe', 'lib', 'flics', 'laid', 'attendre', 'pouse', 'mesure', 'rouge', 'paniqu', 'venue', 'voyons', 'su', 'expliquerai', 'noy', 'avocat', 'attendons', 'cile', 'devrait', 'demand', 'souci', 'nu', 'compte', 'sors', 'condamn', 'voici', 'arriv', 'effet', 'imitation', 'pays', 'faits', 'lirai', 'caviar', 'conte', 'teignez', 'mary', 'incluse', 'agissait', 'adieu', 'rationnel', 'ouvrirai', 'eux', 'abandonn', 'skier', 'chauffez', 'normales', 'verrouill', 'tranquille', 'souvent', 'furieux', 'apeur', 'crainte', 'prudentes', 'aucun', 'terrible', 'forces', 'grassouillette', 'voitures', 'discut', 'gagner', 'retire', 'plais', 'incapable', 'suisse', 'arri', 'geste', 'hauss', 'ant', 'lev', 'malpoli', 'baiss', 'fruits', 'irez', 'important', 'seule', 'pars', 'innocent', 'manqu', 'ceux', 'yeux', 'hideux', 'rendez', 'louch', 'brouillerons', 'sou', 'pari', 'prudents', 'coupable', 've', 'accepterais', 'place', 'viendra', 'donn', 'flemmard', 'sournoise', 'ri', 'seul', 'satisfaite', 'saigner', 'las', 'choses', 'excuser', 'marrant', 'inqui', 'veillez', 'mon', 'gloussa', 'assieds', 'bon', 'grande', 'construite', 'discr', 'continuer', 'saufs', 'partie', 'missionna', 'cd', 'couard', 'alors', 'usage', 'oublie', 'ira', 'abandonnez', 'mords', 'creuse', 'pouvais', 'reposer', 'chanteuse', 'mettrai', 'plant', 'embrass', 'courses', 'preuves', 'surfeur', 'nerv', 'idiote', 'chou', 'gagn', 'sommeil', 'si', 'enfuit', 'cache', 'nagerons', 'chanter', 'saute', 'faux', 'fit', 'offens', 'suis', 'sept', 'reculez', 'haricots', 'fain', 'chanceux', 'loign', 'invent', 'tendue', 'tie', 'commence', 'cide', 'agriculteur', 'grossiers', 'effray', 'apporte', 'blanc', 'ros', 'ste', 'perdus', 'faut', 'vieux', 'ge', 'timide', 'patent', 'absurdit', 'curit', 'entrerai', 'grandes', 'tien', 'jazz', 'relaxe', 'minutieux', 'incroyable', 'ok', 'tudier', 'pigez', 'minces', 'jeune', 'simulation', 'initi', 'chiqu', 'bois', 'fonctionn', 'paiera', 'claire', 'talons', 'bleu', 'abandonnerai', 'joues', 'trouve', 'frousse', 'roulez', 'boulanger', 'foies', 'approche', 'davantage', 'asseyez', 'commen', 'irai', 'ceci', 'fant', 'continuez', 'devrais', 'croch', 'impitoyables', 'entretenues', 'passa', 'reviendrai', 'ouvre', 'eau', 'grouiller', 'propre', 'craignez', 'gauche', 'ne', 'renvers', 'quoi', 'dr', 'ouais', 'divisons', 'aucune', 'fille', 'gosse', 'discret', 'demandez', 'cartez', 'binoclard', 'ticuleux', 'goberais', 'touchez', 'haussa', 'pondez', 'grossi', 'disparu', 'impartiale', 'jeux', 'battus', 'impartial', 'avait', 'arrive', 'assu', 'toujours', 'connu', 'discutions', 'hasarde', 'danser', 'secou', 'amusante', 'ils', 'res', 'devais', 'panique', 'contredanse', 'attentivement', 'chanterai', 'testent', 'glouss', 'dollars', 'transpir', 'sauv', ' ...

# %%
decoder_input=[one_hot(word, len(unique_words_output)) for word in decoder_input_data]
decoder_input
# Out:
# [[1056, 369],
#  [1056, 1528],
#  [1056, 1438],
#  [1056, 2156],
#  [1056, 806, 2052],
#  [1056, 393, 276],
#  [1056, 80, 2001],
#  [1056, 1984],
#  [1056, 806, 1152],
#  [1056, 463],
#  [1056, 323, 852, 276],
#  [1056, 1225],
#  [1056, 1639],
#  [2152, 586],
#  [2152, 586],
#  [1609, 99, 1158, 806, 1336, 1535, 2046, 30, 586],
#  [1336, 1535, 2046, 30, 586],
#  [2157, 99, 1574, 1336, 1979, 586],
#  [806, 1951, 586],
#  [1469, 1574, 806, 586],
#  [1460, 2052, 586],
#  [1869, 1068, 694, 1284, 586],
#  [665, 1068, 694, 2134, 586],
#  [1869, 1068, 975, 586],
#  [665, 1068, 1883, 586],
#  [1869, 1140, 548, 586],
#  [665, 1140, 548, 586],
#  [1869, 1140, 1786, 586],
#  [665, 1140, 1786, 586],
#  [1869, 1292, 586],
#  [665, 1292, 586],
#  [1869, 2065, 40, 586],
#  [665, 2065, 40, 586],
#  [1284, 1543, 1574, 475, 586],
#  [851, 476, 586],
#  [851, 1367, 586],
#  [851, 1951, 56, 586],
#  [851, 1751, 586],
#  [851, 1335, 586],
#  [851, 116, 586],
#  [851, 806, 2159, 586],
#  [851, 806, 220, 119, 1535, 432, 856, 586],
#  [851, 1574, 390, 178, 1535, 1858, 586],
#  [851, 1574, 2077, 586],
#  [851, 1574, 390, 720, 517, 586],
#  [851, 1574, 428, 586],
#  [851, 1574, 1786, 586],
#  [1617, 766, 851, 586],
#  [449, 766, 851, 586],
#  [553, 1660, 586],
#  [977, 1535, 581, 586],
#  [553, 1535, 581, 586],
#  [553, 1284, 586],
#  [1855, 1330, 586],
#  [1225, 1239, 586],
#  [1225, 80, 586],
#  [1639, 1239, 586],
#  [1639, 80, 586],
#  [801, 586],
#  [449, 801, 586],
#  [1617, 801, 586],
#  [1567, 731, 694, 1284, 1064, 1917, 586],
#  [1567, 361, 1118, 874, 586],
#  [1567, 361, 1118, 874, 586],
#  [1567, 80, 361, 220, 586],
#  [1567, 361, 1536, 586],
#  [1567, 80, 361, 1360, 586],
#  [1567, 80, 361, 869, 586],
#  [1567, 361, 317, 586],
#  [1567, 200, 1550, 586],
#  [1567, 361, 200, 586],
#  [1567, 1567, 731, 1061, 586],
#  [1567, 1567, 731, 433, 586],
#  [1567, 1567, 2062, 1896, 586],
#  [1567, 1380, 1550, 586],
#  [1567, 361, 1696, 586],
#  [1567, 731, 829, 1284, 2153, 586],
#  [1567, 731, 829, 2134, 2153, 586],
#  [1567, 1724, 586],
#  [1567, 149, 586],
#  [1567, 80, 939, 586],
#  [1567, 706, 586],
#  [1567, 361, 1431, 586],
#  [1567, 731, 1029, 586],
#  ...]

# %%
decoder_input_data=pad_sequences(decoder_input, maxlen=max_len_output, padding='post')
decoder_input_data.shape
# Out:
# (5000, 10)

# %%
decoder_target_data=pad_sequences(decoder_target, maxlen=max_len_output, padding='post')
decoder_target_data.shape
# Out:
# (5000, 10)

# %%
from tensorflow.keras.utils import to_categorical

decoder_target_data = to_categorical(
    decoder_target_data,  # Changed from max_len_output to the actual data
    num_classes=len(unique_words_output)     # same as your output layer vocab size
)
decoder_target_data.shape
# Out:
# (5000, 10, 2203)

# %% [markdown]
# # ===== Encoder =====

# %%
from keras.layers import Embedding, LSTM, Input

encoder_inputs = Input(shape=(None,))   # input is a sequence of word indices
x = Embedding(input_dim=len(unique_words_input), output_dim=127, input_length=max_len_input)(encoder_inputs)

# LSTM encoder
encoder_lstm = LSTM(259, return_state=True)  # return_state gives hidden + cell states
encoder_outputs, state_h, state_c = encoder_lstm(x)

# Encoder states (to pass into decoder)
encoder_states = [state_h, state_c]
# Out:
# /home/hammadali08/.local/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# # ===== Decoder =====

# %%
decoder_inputs = Input(shape=(None,))  # target sequence input
decoder_embedding = Embedding(input_dim=len(unique_words_output), output_dim=40, input_length=max_len_output)(decoder_inputs)

# LSTM decoder, initialized with encoder states
decoder_lstm = LSTM(259, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)

# %% [markdown]
# # Final dense layer to predict word probabilities

# %%
from tensorflow.keras.layers import Dense
decoder_dense = Dense(len(unique_words_output), activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
from tensorflow.keras.models import Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit([input_padding, decoder_input_data], decoder_target_data,
          batch_size=50,
          epochs=15,
          validation_split=0.2)
# Out:
# Epoch 1/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.5638 - loss: 3.3106 - val_accuracy: 0.5585 - val_loss: 2.5716
# Epoch 2/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.6674 - loss: 2.0395 - val_accuracy: 0.6411 - val_loss: 2.3056
# Epoch 3/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 15s 182ms/step - accuracy: 0.6918 - loss: 1.8699 - val_accuracy: 0.6442 - val_loss: 2.2336
# Epoch 4/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.7007 - loss: 1.7734 - val_accuracy: 0.6534 - val_loss: 2.1706
# Epoch 5/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 145ms/step - accuracy: 0.7104 - loss: 1.6931 - val_accuracy: 0.6713 - val_loss: 2.0916
# Epoch 6/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 13s 166ms/step - accuracy: 0.7193 - loss: 1.6095 - val_accuracy: 0.6826 - val_loss: 2.0184
# Epoch 7/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.7309 - loss: 1.5263 - val_accuracy: 0.6934 - val_loss: 1.9658
# Epoch 8/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 22s 151ms/step - accuracy: 0.7388 - loss: 1.4598 - val_accuracy: 0.6970 - val_loss: 1.9328
# Epoch 9/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.7459 - loss: 1.3953 - val_accuracy: 0.7004 - val_loss: 1.9052
# Epoch 10/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 21s 143ms/step - accuracy: 0.7507 - loss: 1.3385 - val_accuracy: 0.7074 - val_loss: 1.8953
# Epoch 11/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.7557 - loss: 1.2905 - val_accuracy: 0.7146 - val_loss: 1.8727
# Epoch 12/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - accuracy: 0.7607 - loss: 1.2417 - val_accuracy: 0.7166 - val_loss: 1.8643
# Epoch 13/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - accuracy: 0.7657 - loss: 1.1946 - val_accuracy: 0.7135 - val_loss: 1.8637
# Epoch 14/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 0.7713 - loss: 1.1498 - val_accuracy: 0.7195 - val_loss: 1.8609
# Epoch 15/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.7750 - loss: 1.1097 - val_accuracy: 0.7227 - val_loss: 1.8591
