# %%
import matplotlib.pyplot as plt

# %%
a=[2,3,4,5]
b=[6,7,8,9]
c=[10,11,5,13]
d=['b','g','r','c']

# %%
plt.bar(a,b,color=d,width=0.4)
plt.show()

# %%
plt.plot(b,c,color='blue')
plt.scatter(b,c)
plt.show()
