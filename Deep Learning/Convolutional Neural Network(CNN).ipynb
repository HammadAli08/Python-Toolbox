# %%
import pandas as pd
import tensorflow

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
cnn = Sequential()

# %%
cnn.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
cnn.add(MaxPooling2D(pool_size=(2, 2)))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))
cnn.add(Flatten())
# Out:
# /home/hammadali08/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(Dense(128, activation='relu'))
cnn.add(Dense(64, activation='relu'))
cnn.add(Dense(32, activation='relu'))
cnn.add(Dense(16, activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Dense(8, activation='relu'))
cnn.add(Dense(4, activation='relu'))
cnn.add(Dense(1, activation='sigmoid'))

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        r'/home/hammadali08/Vidoes/CSV file/Photos Datset/Train data',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

test_generator = test_datagen.flow_from_directory(
        r'/home/hammadali08/Vidoes/CSV file/Photos Datset/test data',
        target_size=(64 , 64),
        batch_size=32,
        class_mode='binary')

cnn.fit(train_generator,
        steps_per_epoch=400,epochs=25,validation_data=test_generator)
# Out:
# Found 22973 images belonging to 2 classes.
# Found 2024 images belonging to 2 classes.
# /home/hammadali08/.local/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 106/400 ━━━━━━━━━━━━━━━━━━━━ 39s 136ms/step - accuracy: 0.5603 - loss: 0.6852
# /home/hammadali08/.local/lib/python3.12/site-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 57s 134ms/step - accuracy: 0.6490 - loss: 0.6245 - val_accuracy: 0.5400 - val_loss: 0.7796
# Epoch 2/25
# 318/400 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - accuracy: 0.7085 - loss: 0.5687
# /home/hammadali08/.local/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 43s 107ms/step - accuracy: 0.7163 - loss: 0.5585 - val_accuracy: 0.6779 - val_loss: 0.6062
# Epoch 3/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 52s 129ms/step - accuracy: 0.7349 - loss: 0.5317 - val_accuracy: 0.7441 - val_loss: 0.5393
# Epoch 4/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 40s 99ms/step - accuracy: 0.7564 - loss: 0.5047 - val_accuracy: 0.7149 - val_loss: 0.5314
# Epoch 5/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 52s 129ms/step - accuracy: 0.7660 - loss: 0.4910 - val_accuracy: 0.7451 - val_loss: 0.5417
# Epoch 6/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 42s 105ms/step - accuracy: 0.7651 - loss: 0.4773 - val_accuracy: 0.7688 - val_loss: 0.4731
# Epoch 7/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 55s 138ms/step - accuracy: 0.7812 - loss: 0.4645 - val_accuracy: 0.7564 - val_loss: 0.4798
# Epoch 8/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 44s 109ms/step - accuracy: 0.7844 - loss: 0.4562 - val_accuracy: 0.7861 - val_loss: 0.4708
# Epoch 9/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 49s 123ms/step - accuracy: 0.7878 - loss: 0.4516 - val_accuracy: 0.5277 - val_loss: 1.7518
# Epoch 10/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 43s 107ms/step - accuracy: 0.7949 - loss: 0.4343 - val_accuracy: 0.7935 - val_loss: 0.4394
# Epoch 11/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 51s 128ms/step - accuracy: 0.8035 - loss: 0.4240 - val_accuracy: 0.6151 - val_loss: 0.9174
# Epoch 12/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 37s 92ms/step - accuracy: 0.8064 - loss: 0.4172 - val_accuracy: 0.7895 - val_loss: 0.4567
# Epoch 13/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 48s 119ms/step - accuracy: 0.8034 - loss: 0.4247 - val_accuracy: 0.7416 - val_loss: 0.5406
# Epoch 14/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 39s 97ms/step - accuracy: 0.8091 - loss: 0.4099 - val_accuracy: 0.7752 - val_loss: 0.5071
# Epoch 15/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 49s 122ms/step - accuracy: 0.8229 - loss: 0.3912 - val_accuracy: 0.8291 - val_loss: 0.3796
# Epoch 16/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 39s 97ms/step - accuracy: 0.8134 - loss: 0.3952 - val_accuracy: 0.7510 - val_loss: 0.5646
# Epoch 17/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 48s 120ms/step - accuracy: 0.8193 - loss: 0.3888 - val_accuracy: 0.8039 - val_loss: 0.4683
# Epoch 18/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 44s 110ms/step - accuracy: 0.8157 - loss: 0.3903 - val_accuracy: 0.8231 - val_loss: 0.4097
# Epoch 19/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 51s 127ms/step - accuracy: 0.8311 - loss: 0.3697 - val_accuracy: 0.7900 - val_loss: 0.4464
# Epoch 20/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 38s 94ms/step - accuracy: 0.8335 - loss: 0.3707 - val_accuracy: 0.8162 - val_loss: 0.4015
# Epoch 21/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 54s 134ms/step - accuracy: 0.8335 - loss: 0.3664 - val_accuracy: 0.8083 - val_loss: 0.4646
# Epoch 22/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 42s 106ms/step - accuracy: 0.8432 - loss: 0.3504 - val_accuracy: 0.8330 - val_loss: 0.3794
# Epoch 23/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 50s 125ms/step - accuracy: 0.8430 - loss: 0.3543 - val_accuracy: 0.8394 - val_loss: 0.3528
# Epoch 24/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 45s 113ms/step - accuracy: 0.8467 - loss: 0.3445 - val_accuracy: 0.7841 - val_loss: 0.4743
# Epoch 25/25
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 53s 132ms/step - accuracy: 0.8501 - loss: 0.3402 - val_accuracy: 0.8281 - val_loss: 0.3754

# %%
from keras.preprocessing import image
import numpy as np
import pandas as pd

# %%
img=image.load_img('/home/hammadali08/Downloads/a7ee6575-22e6-4567-b95b-063c3c86e0d5.jpeg',target_size=(64,64))
img1=image.load_img('/home/hammadali08/Vidoes/CSV file/Photos Datset/test data/Cat_test/101.jpg',target_size=(64,64))

# %%
img=image.img_to_array(img)
img1=image.img_to_array(img1)

# %%
img=np.expand_dims(img,axis=0)
img1=np.expand_dims(img1,axis=0)

# %%
im=cnn.predict(img)
if im>0.5:
    print('Dog')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Dog

# %%
cnn.predict(img1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# array([[1.]], dtype=float32)

# %%
prd_y=cnn.predict(test_generator)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step

# %%
prd_y_data=[]
for i in prd_y:
    if i>=0.5:
        prd_y_data.append('Dog')
    else:
        prd_y_data.append('Cat')

# %%
data=pd.DataFrame(prd_y_data)
data.value_counts()
# Out:
# 0
# Dog    1090
# Cat     934
# Name: count, dtype: int64

# %%
prd=cnn.predict(train_generator)
# Out:
# 711/718 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# /home/hammadali08/.local/lib/python3.12/site-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 56s 78ms/step

# %%
prd_data=[]
for i in prd:
    if i>=0.5:
        prd_data.append('Dog')
    else:
        prd_data.append('Cat')

# %%
data1=pd.DataFrame({'Predictions':prd_data})
data1.value_counts()
# Out:
# Predictions
# Cat            11898
# Dog            11075
# Name: count, dtype: int64
